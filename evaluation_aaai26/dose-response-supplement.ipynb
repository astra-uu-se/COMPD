# %% [markdown]
# # Dose Response Plots
#
# Here we generate all plots related to dose-response experiments used in the manuscript, including the supplement.
#
# We begin by importing required packages.

# %%
import numpy as np
import libraries.utilities as util

tables_dir = "latex-tables/"
figures_dir = "generated-plots/dose-response-supplement/"
data_dir = "generated-data/dose-response/"

# %% [markdown]
# ## Plotting Absolute IC50 and Max (height) diff Figures
#
# ### Bowl-shaped effect, without using negative controls to estimate the curves

# %%
## To get the same y axis in subplots in the same figure
y_max_absic = 0.3
y_max_d_diff = 14

# %%
# 6 doses. Not using neg controls when estimating the curve. (currently on the supplement)
fig_name = "-6doses-dil18-bowl-0.055"

## Data files
absolute_ic50_data_1rep = np.loadtxt(data_dir+'absolute_ic50_data-48-6-dil18-1-0.055-20250706-curve_info-new-reg.csv', delimiter=',', dtype='str')
absolute_ic50_data_2rep = np.loadtxt(data_dir+'absolute_ic50_data-24-6-dil18-2-0.055-20250706-curve_info-new-reg.csv', delimiter=',', dtype='str')
absolute_ic50_data_3rep = np.loadtxt(data_dir+'absolute_ic50_data-16-6-dil18-3-0.055-20250706-curve_info-new-reg.csv', delimiter=',', dtype='str')

util.generate_absic50_ddiff_tables(absolute_ic50_data_1rep, absolute_ic50_data_2rep, absolute_ic50_data_3rep, fig_name, figures_dir, tables_dir, y_max_absic,
y_max_d_diff)
# Out:
# p-value annotation legend:
#       ns: 1.00e-04 < p <= 1.00e+00
#        *: 1.00e-12 < p <= 1.00e-04
#       **: 1.00e-43 < p <= 1.00e-12
#      ***: p <= 1.00e-43
#
# 2_Random vs. 2_PLAID: t-test independent samples, P_val:1.478e-12 t=7.081e+00
# 2_PLAID vs. 2_COMPD: t-test independent samples, P_val:1.567e-03 t=3.162e+00
# 3_Random vs. 3_PLAID: t-test independent samples, P_val:3.461e-49 t=1.481e+01
# 3_PLAID vs. 3_COMPD: t-test independent samples, P_val:1.173e-17 t=-8.568e+00
# 1_Random vs. 1_PLAID: t-test independent samples, P_val:2.151e-42 t=1.366e+01
# 1_PLAID vs. 1_COMPD: t-test independent samples, P_val:4.744e-04 t=3.495e+00
# 2_Random vs. 2_COMPD: t-test independent samples, P_val:5.091e-24 t=1.012e+01
# 3_Random vs. 3_COMPD: t-test independent samples, P_val:1.710e-12 t=7.063e+00
# 1_Random vs. 1_COMPD: t-test independent samples, P_val:3.462e-64 t=1.695e+01
# p-value annotation legend:
#       ns: 1.00e-04 < p <= 1.00e+00
#        *: 1.00e-12 < p <= 1.00e-04
# ...

# %%
# 6 doses. Not using neg controls when estimating the curve. (currently on the supplement)
fig_name = "-6doses-dil18-bowl-0.085"
absolute_ic50_data_1rep = np.loadtxt(data_dir+'absolute_ic50_data-48-6-dil18-1-0.085-20250706-curve_info-new-reg.csv', delimiter=',', dtype='str')
absolute_ic50_data_2rep = np.loadtxt(data_dir+'absolute_ic50_data-24-6-dil18-2-0.085-20250706-curve_info-new-reg.csv', delimiter=',', dtype='str')
absolute_ic50_data_3rep = np.loadtxt(data_dir+'absolute_ic50_data-16-6-dil18-3-0.085-20250706-curve_info-new-reg.csv', delimiter=',', dtype='str')

util.generate_absic50_ddiff_tables(absolute_ic50_data_1rep, absolute_ic50_data_2rep, absolute_ic50_data_3rep, fig_name, figures_dir, tables_dir, y_max_absic,
y_max_d_diff)
# Out:
# p-value annotation legend:
#       ns: 1.00e-04 < p <= 1.00e+00
#        *: 1.00e-12 < p <= 1.00e-04
#       **: 1.00e-43 < p <= 1.00e-12
#      ***: p <= 1.00e-43
#
# 2_Random vs. 2_PLAID: t-test independent samples, P_val:9.984e-13 t=7.136e+00
# 2_PLAID vs. 2_COMPD: t-test independent samples, P_val:1.305e-03 t=3.215e+00
# 3_Random vs. 3_PLAID: t-test independent samples, P_val:3.123e-42 t=1.367e+01
# 3_PLAID vs. 3_COMPD: t-test independent samples, P_val:7.333e-16 t=-8.075e+00
# 1_Random vs. 1_PLAID: t-test independent samples, P_val:4.120e-38 t=1.292e+01
# 1_PLAID vs. 1_COMPD: t-test independent samples, P_val:4.733e-01 t=7.172e-01
# 2_Random vs. 2_COMPD: t-test independent samples, P_val:3.545e-24 t=1.016e+01
# 3_Random vs. 3_COMPD: t-test independent samples, P_val:5.076e-10 t=6.222e+00
# 1_Random vs. 1_COMPD: t-test independent samples, P_val:4.299e-41 t=1.344e+01
# p-value annotation legend:
#       ns: 1.00e-04 < p <= 1.00e+00
#        *: 1.00e-12 < p <= 1.00e-04
# ...

# %%
# 8 doses. Not using neg controls when estimating the curve. (currently on the supplement)
fig_name = "-8doses-dil8-bowl-0.055"

absolute_ic50_data_1rep = np.loadtxt(data_dir+'absolute_ic50_data-36-8-dil8-1-0.055-20250706-curve_info-new-reg.csv', delimiter=',', dtype='str')
absolute_ic50_data_2rep = np.loadtxt(data_dir+'absolute_ic50_data-18-8-dil8-2-0.055-20250706-curve_info-new-reg.csv', delimiter=',', dtype='str')
absolute_ic50_data_3rep = np.loadtxt(data_dir+'absolute_ic50_data-12-8-dil8-3-0.055-20250706-curve_info-new-reg.csv', delimiter=',', dtype='str')

util.generate_absic50_ddiff_tables(absolute_ic50_data_1rep, absolute_ic50_data_2rep, absolute_ic50_data_3rep, fig_name, figures_dir, tables_dir, y_max_absic,
y_max_d_diff)
# Out:
# p-value annotation legend:
#       ns: 1.00e-04 < p <= 1.00e+00
#        *: 1.00e-12 < p <= 1.00e-04
#       **: 1.00e-43 < p <= 1.00e-12
#      ***: p <= 1.00e-43
#
# 2_Random vs. 2_PLAID: t-test independent samples, P_val:3.665e-04 t=3.564e+00
# 2_PLAID vs. 2_COMPD: t-test independent samples, P_val:9.133e-03 t=2.607e+00
# 3_Random vs. 3_PLAID: t-test independent samples, P_val:1.187e-29 t=1.135e+01
# 3_PLAID vs. 3_COMPD: t-test independent samples, P_val:9.698e-07 t=-4.901e+00
# 1_Random vs. 1_PLAID: t-test independent samples, P_val:4.664e-19 t=8.926e+00
# 1_PLAID vs. 1_COMPD: t-test independent samples, P_val:4.063e-09 t=-5.883e+00
# 2_Random vs. 2_COMPD: t-test independent samples, P_val:1.269e-09 t=6.075e+00
# 3_Random vs. 3_COMPD: t-test independent samples, P_val:9.305e-11 t=6.485e+00
# 1_Random vs. 1_COMPD: t-test independent samples, P_val:9.675e-04 t=3.300e+00
# p-value annotation legend:
#       ns: 1.00e-04 < p <= 1.00e+00
#        *: 1.00e-12 < p <= 1.00e-04
# ...

# %%
# 8 doses. Not using neg controls when estimating the curve. (currently on the supplement)
fig_name = "-8doses-dil8-bowl-0.085"
absolute_ic50_data_1rep = np.loadtxt(data_dir+'absolute_ic50_data-36-8-dil8-1-0.085-20250706-curve_info-new-reg.csv', delimiter=',', dtype='str')
absolute_ic50_data_2rep = np.loadtxt(data_dir+'absolute_ic50_data-18-8-dil8-2-0.085-20250706-curve_info-new-reg.csv', delimiter=',', dtype='str')
absolute_ic50_data_3rep = np.loadtxt(data_dir+'absolute_ic50_data-12-8-dil8-3-0.085-20250706-curve_info-new-reg.csv', delimiter=',', dtype='str')

util.generate_absic50_ddiff_tables(absolute_ic50_data_1rep, absolute_ic50_data_2rep, absolute_ic50_data_3rep, fig_name, figures_dir, tables_dir, y_max_absic,
y_max_d_diff)
# Out:
# p-value annotation legend:
#       ns: 1.00e-04 < p <= 1.00e+00
#        *: 1.00e-12 < p <= 1.00e-04
#       **: 1.00e-43 < p <= 1.00e-12
#      ***: p <= 1.00e-43
#
# 2_Random vs. 2_PLAID: t-test independent samples, P_val:3.316e-04 t=3.590e+00
# 2_PLAID vs. 2_COMPD: t-test independent samples, P_val:1.414e-04 t=3.807e+00
# 3_Random vs. 3_PLAID: t-test independent samples, P_val:9.880e-29 t=1.116e+01
# 3_PLAID vs. 3_COMPD: t-test independent samples, P_val:1.107e-08 t=-5.719e+00
# 1_Random vs. 1_PLAID: t-test independent samples, P_val:9.026e-14 t=7.458e+00
# 1_PLAID vs. 1_COMPD: t-test independent samples, P_val:5.615e-13 t=-7.213e+00
# 2_Random vs. 2_COMPD: t-test independent samples, P_val:2.974e-13 t=7.302e+00
# 3_Random vs. 3_COMPD: t-test independent samples, P_val:8.181e-08 t=5.367e+00
# 1_Random vs. 1_COMPD: t-test independent samples, P_val:6.488e-01 t=4.555e-01
# p-value annotation legend:
#       ns: 1.00e-04 < p <= 1.00e+00
#        *: 1.00e-12 < p <= 1.00e-04
# ...

# %%
# 12 doses. Not using neg controls when estimating the curve. (currently on the supplement)
fig_name = "-12doses-dil4-bowl-0.055"
absolute_ic50_data_1rep = np.loadtxt(data_dir+'absolute_ic50_data-24-12-dil4-1-0.055-20250706-curve_info-new-reg.csv', delimiter=',', dtype='str')
absolute_ic50_data_2rep = np.loadtxt(data_dir+'absolute_ic50_data-12-12-dil4-2-0.055-20250706-curve_info-new-reg.csv', delimiter=',', dtype='str')
absolute_ic50_data_3rep = np.loadtxt(data_dir+'absolute_ic50_data-8-12-dil4-3-0.055-20250706-curve_info-new-reg.csv', delimiter=',', dtype='str')

util.generate_absic50_ddiff_tables(absolute_ic50_data_1rep, absolute_ic50_data_2rep, absolute_ic50_data_3rep, fig_name, figures_dir, tables_dir, y_max_absic,
y_max_d_diff)
# Out:
# p-value annotation legend:
#       ns: 1.00e-04 < p <= 1.00e+00
#        *: 1.00e-12 < p <= 1.00e-04
#       **: 1.00e-43 < p <= 1.00e-12
#      ***: p <= 1.00e-43
#
# 2_Random vs. 2_PLAID: t-test independent samples, P_val:2.592e-24 t=1.020e+01
# 2_PLAID vs. 2_COMPD: t-test independent samples, P_val:9.139e-02 t=-1.688e+00
# 3_Random vs. 3_PLAID: t-test independent samples, P_val:1.508e-73 t=1.838e+01
# 3_PLAID vs. 3_COMPD: t-test independent samples, P_val:5.227e-05 t=-4.048e+00
# 1_Random vs. 1_PLAID: t-test independent samples, P_val:3.081e-24 t=1.017e+01
# 1_PLAID vs. 1_COMPD: t-test independent samples, P_val:5.556e-15 t=7.820e+00
# 2_Random vs. 2_COMPD: t-test independent samples, P_val:6.553e-17 t=8.370e+00
# 3_Random vs. 3_COMPD: t-test independent samples, P_val:4.319e-50 t=1.501e+01
# 1_Random vs. 1_COMPD: t-test independent samples, P_val:2.942e-69 t=1.766e+01
# p-value annotation legend:
#       ns: 1.00e-04 < p <= 1.00e+00
#        *: 1.00e-12 < p <= 1.00e-04
# ...

# %%
# 12 doses. Not using neg controls when estimating the curve. (currently on the supplement)
fig_name = "-12doses-dil4-bowl-0.085"
absolute_ic50_data_1rep = np.loadtxt(data_dir+'absolute_ic50_data-24-12-dil4-1-0.085-20250706-curve_info-new-reg.csv', delimiter=',', dtype='str')
absolute_ic50_data_2rep = np.loadtxt(data_dir+'absolute_ic50_data-12-12-dil4-2-0.085-20250706-curve_info-new-reg.csv', delimiter=',', dtype='str')
absolute_ic50_data_3rep = np.loadtxt(data_dir+'absolute_ic50_data-8-12-dil4-3-0.085-20250706-curve_info-new-reg.csv', delimiter=',', dtype='str')

util.generate_absic50_ddiff_tables(absolute_ic50_data_1rep, absolute_ic50_data_2rep, absolute_ic50_data_3rep, fig_name, figures_dir, tables_dir, y_max_absic,
y_max_d_diff)
# Out:
# p-value annotation legend:
#       ns: 1.00e-04 < p <= 1.00e+00
#        *: 1.00e-12 < p <= 1.00e-04
#       **: 1.00e-43 < p <= 1.00e-12
#      ***: p <= 1.00e-43
#
# 2_Random vs. 2_PLAID: t-test independent samples, P_val:1.499e-19 t=9.064e+00
# 2_PLAID vs. 2_COMPD: t-test independent samples, P_val:1.100e-01 t=-1.598e+00
# 3_Random vs. 3_PLAID: t-test independent samples, P_val:3.788e-68 t=1.765e+01
# 3_PLAID vs. 3_COMPD: t-test independent samples, P_val:1.166e-04 t=-3.856e+00
# 1_Random vs. 1_PLAID: t-test independent samples, P_val:1.954e-18 t=8.769e+00
# 1_PLAID vs. 1_COMPD: t-test independent samples, P_val:8.234e-14 t=7.472e+00
# 2_Random vs. 2_COMPD: t-test independent samples, P_val:3.127e-13 t=7.299e+00
# 3_Random vs. 3_COMPD: t-test independent samples, P_val:2.005e-46 t=1.442e+01
# 1_Random vs. 1_COMPD: t-test independent samples, P_val:4.495e-59 t=1.626e+01
# p-value annotation legend:
#       ns: 1.00e-04 < p <= 1.00e+00
#        *: 1.00e-12 < p <= 1.00e-04
# ...

# %% [markdown]
# ### Bowl-shaped effect, using 4 neg controls when estimating the curve

# %%
## To get the same y axis in subplots in the same figure
y_max_absic = 0.4
y_max_d_diff = 14

leg_ncol_d_diff = 1
leg_loc_d_diff = "upper right"

# %%
# 6 doses. Using 4 neg controls when estimating the curve. (currently on the supplement)
fig_name = "-6doses-dil18-bowl-neg-controls-0.055"
absolute_ic50_data_1rep = np.loadtxt(data_dir+'absolute_ic50_data-48-6-dil18-1-0.055-20250706-bowl-neg-control-new-reg.csv', delimiter=',', dtype='str')
absolute_ic50_data_2rep = np.loadtxt(data_dir+'absolute_ic50_data-24-6-dil18-2-0.055-20250706-bowl-neg-control-new-reg.csv', delimiter=',', dtype='str')
absolute_ic50_data_3rep = np.loadtxt(data_dir+'absolute_ic50_data-16-6-dil18-3-0.055-20250706-bowl-neg-control-new-reg.csv', delimiter=',', dtype='str')

util.generate_absic50_ddiff_tables(absolute_ic50_data_1rep, absolute_ic50_data_2rep, absolute_ic50_data_3rep, fig_name, figures_dir, tables_dir, y_max_absic,
y_max_d_diff,leg_ncol_d_diff,leg_loc_d_diff)
# Out:
# p-value annotation legend:
#       ns: 1.00e-04 < p <= 1.00e+00
#        *: 1.00e-12 < p <= 1.00e-04
#       **: 1.00e-43 < p <= 1.00e-12
#      ***: p <= 1.00e-43
#
# 2_Random vs. 2_PLAID: t-test independent samples, P_val:2.767e-13 t=7.310e+00
# 2_PLAID vs. 2_COMPD: t-test independent samples, P_val:7.146e-03 t=2.690e+00
# 3_Random vs. 3_PLAID: t-test independent samples, P_val:1.411e-47 t=1.455e+01
# 3_PLAID vs. 3_COMPD: t-test independent samples, P_val:5.432e-17 t=-8.389e+00
# 1_Random vs. 1_PLAID: t-test independent samples, P_val:1.279e-42 t=1.370e+01
# 1_PLAID vs. 1_COMPD: t-test independent samples, P_val:2.214e-03 t=3.060e+00
# 2_Random vs. 2_COMPD: t-test independent samples, P_val:8.727e-23 t=9.838e+00
# 3_Random vs. 3_COMPD: t-test independent samples, P_val:7.011e-12 t=6.864e+00
# 1_Random vs. 1_COMPD: t-test independent samples, P_val:2.579e-61 t=1.655e+01
# p-value annotation legend:
#       ns: 1.00e-04 < p <= 1.00e+00
#        *: 1.00e-12 < p <= 1.00e-04
# ...

# %%
# 6 doses (currently on the paper. Using 4 neg controls in the curve)
fig_name = "-6doses-dil18-bowl-neg-controls-0.085"
absolute_ic50_data_1rep = np.loadtxt(data_dir+'absolute_ic50_data-48-6-dil18-1-0.085-20250706-bowl-neg-control-new-reg.csv', delimiter=',', dtype='str')
absolute_ic50_data_2rep = np.loadtxt(data_dir+'absolute_ic50_data-24-6-dil18-2-0.085-20250706-bowl-neg-control-new-reg.csv', delimiter=',', dtype='str')
absolute_ic50_data_3rep = np.loadtxt(data_dir+'absolute_ic50_data-16-6-dil18-3-0.085-20250706-bowl-neg-control-new-reg.csv', delimiter=',', dtype='str')

util.generate_absic50_ddiff_tables(absolute_ic50_data_1rep, absolute_ic50_data_2rep, absolute_ic50_data_3rep, fig_name, figures_dir, tables_dir, y_max_absic,
y_max_d_diff,leg_ncol_d_diff,leg_loc_d_diff)
# Out:
# p-value annotation legend:
#       ns: 1.00e-04 < p <= 1.00e+00
#        *: 1.00e-12 < p <= 1.00e-04
#       **: 1.00e-43 < p <= 1.00e-12
#      ***: p <= 1.00e-43
#
# 2_Random vs. 2_PLAID: t-test independent samples, P_val:1.410e-12 t=7.088e+00
# 2_PLAID vs. 2_COMPD: t-test independent samples, P_val:4.624e-04 t=3.502e+00
# 3_Random vs. 3_PLAID: t-test independent samples, P_val:1.550e-41 t=1.355e+01
# 3_PLAID vs. 3_COMPD: t-test independent samples, P_val:5.797e-16 t=-8.104e+00
# 1_Random vs. 1_PLAID: t-test independent samples, P_val:1.253e-38 t=1.301e+01
# 1_PLAID vs. 1_COMPD: t-test independent samples, P_val:3.770e-01 t=8.835e-01
# 2_Random vs. 2_COMPD: t-test independent samples, P_val:3.170e-25 t=1.039e+01
# 3_Random vs. 3_COMPD: t-test independent samples, P_val:9.621e-10 t=6.120e+00
# 1_Random vs. 1_COMPD: t-test independent samples, P_val:9.431e-43 t=1.372e+01
# p-value annotation legend:
#       ns: 1.00e-04 < p <= 1.00e+00
#        *: 1.00e-12 < p <= 1.00e-04
# ...

# %%
# 8 doses (currently on the paper. Using 4 neg controls in the curve)
fig_name = "-8doses-dil8-bowl-neg-controls-0.055"
absolute_ic50_data_1rep = np.loadtxt(data_dir+'absolute_ic50_data-36-8-dil8-1-0.055-20250706-bowl-neg-control-new-reg.csv', delimiter=',', dtype='str')
absolute_ic50_data_2rep = np.loadtxt(data_dir+'absolute_ic50_data-18-8-dil8-2-0.055-20250706-bowl-neg-control-new-reg.csv', delimiter=',', dtype='str')
absolute_ic50_data_3rep = np.loadtxt(data_dir+'absolute_ic50_data-12-8-dil8-3-0.055-20250706-bowl-neg-control-new-reg.csv', delimiter=',', dtype='str')

util.generate_absic50_ddiff_tables(absolute_ic50_data_1rep, absolute_ic50_data_2rep, absolute_ic50_data_3rep, fig_name, figures_dir, tables_dir, y_max_absic,
y_max_d_diff,leg_ncol_d_diff,leg_loc_d_diff)
# Out:
# p-value annotation legend:
#       ns: 1.00e-04 < p <= 1.00e+00
#        *: 1.00e-12 < p <= 1.00e-04
#       **: 1.00e-43 < p <= 1.00e-12
#      ***: p <= 1.00e-43
#
# 2_Random vs. 2_PLAID: t-test independent samples, P_val:1.266e-04 t=3.834e+00
# 2_PLAID vs. 2_COMPD: t-test independent samples, P_val:1.568e-02 t=2.417e+00
# 3_Random vs. 3_PLAID: t-test independent samples, P_val:2.964e-29 t=1.127e+01
# 3_PLAID vs. 3_COMPD: t-test independent samples, P_val:6.091e-06 t=-4.526e+00
# 1_Random vs. 1_PLAID: t-test independent samples, P_val:1.742e-19 t=9.035e+00
# 1_PLAID vs. 1_COMPD: t-test independent samples, P_val:6.147e-09 t=-5.814e+00
# 2_Random vs. 2_COMPD: t-test independent samples, P_val:7.218e-10 t=6.165e+00
# 3_Random vs. 3_COMPD: t-test independent samples, P_val:1.581e-11 t=6.748e+00
# 1_Random vs. 1_COMPD: t-test independent samples, P_val:5.157e-04 t=3.473e+00
# p-value annotation legend:
#       ns: 1.00e-04 < p <= 1.00e+00
#        *: 1.00e-12 < p <= 1.00e-04
# ...

# %%
# 8 doses (currently on the paper. Using 4 neg controls in the curve)
fig_name = "-8doses-dil8-bowl-neg-controls-0.085"
absolute_ic50_data_1rep = np.loadtxt(data_dir+'absolute_ic50_data-36-8-dil8-1-0.085-20250706-bowl-neg-control-new-reg.csv', delimiter=',', dtype='str')
absolute_ic50_data_2rep = np.loadtxt(data_dir+'absolute_ic50_data-18-8-dil8-2-0.085-20250706-bowl-neg-control-new-reg.csv', delimiter=',', dtype='str')
absolute_ic50_data_3rep = np.loadtxt(data_dir+'absolute_ic50_data-12-8-dil8-3-0.085-20250706-bowl-neg-control-new-reg.csv', delimiter=',', dtype='str')

util.generate_absic50_ddiff_tables(absolute_ic50_data_1rep, absolute_ic50_data_2rep, absolute_ic50_data_3rep, fig_name, figures_dir, tables_dir, y_max_absic,
y_max_d_diff,leg_ncol_d_diff,leg_loc_d_diff)
# Out:
# p-value annotation legend:
#       ns: 1.00e-04 < p <= 1.00e+00
#        *: 1.00e-12 < p <= 1.00e-04
#       **: 1.00e-43 < p <= 1.00e-12
#      ***: p <= 1.00e-43
#
# 2_Random vs. 2_PLAID: t-test independent samples, P_val:7.028e-04 t=3.389e+00
# 2_PLAID vs. 2_COMPD: t-test independent samples, P_val:2.651e-05 t=4.203e+00
# 3_Random vs. 3_PLAID: t-test independent samples, P_val:3.245e-30 t=1.146e+01
# 3_PLAID vs. 3_COMPD: t-test independent samples, P_val:1.036e-08 t=-5.730e+00
# 1_Random vs. 1_PLAID: t-test independent samples, P_val:2.180e-13 t=7.341e+00
# 1_PLAID vs. 1_COMPD: t-test independent samples, P_val:5.619e-12 t=-6.892e+00
# 2_Random vs. 2_COMPD: t-test independent samples, P_val:7.653e-14 t=7.484e+00
# 3_Random vs. 3_COMPD: t-test independent samples, P_val:1.590e-08 t=5.656e+00
# 1_Random vs. 1_COMPD: t-test independent samples, P_val:5.067e-01 t=6.640e-01
# p-value annotation legend:
#       ns: 1.00e-04 < p <= 1.00e+00
#        *: 1.00e-12 < p <= 1.00e-04
# ...

# %%
# 12 doses (currently on the paper. Using 4 neg controls in the curve)
fig_name = "-12doses-dil4-bowl-neg-controls-0.055"
absolute_ic50_data_1rep = np.loadtxt(data_dir+'absolute_ic50_data-24-12-dil4-1-0.055-20250706-bowl-neg-control-new-reg.csv', delimiter=',', dtype='str')
absolute_ic50_data_2rep = np.loadtxt(data_dir+'absolute_ic50_data-12-12-dil4-2-0.055-20250706-bowl-neg-control-new-reg.csv', delimiter=',', dtype='str')
absolute_ic50_data_3rep = np.loadtxt(data_dir+'absolute_ic50_data-8-12-dil4-3-0.055-20250706-bowl-neg-control-new-reg.csv', delimiter=',', dtype='str')

util.generate_absic50_ddiff_tables(absolute_ic50_data_1rep, absolute_ic50_data_2rep, absolute_ic50_data_3rep, fig_name, figures_dir, tables_dir, y_max_absic,
y_max_d_diff,leg_ncol_d_diff,leg_loc_d_diff)
# Out:
# p-value annotation legend:
#       ns: 1.00e-04 < p <= 1.00e+00
#        *: 1.00e-12 < p <= 1.00e-04
#       **: 1.00e-43 < p <= 1.00e-12
#      ***: p <= 1.00e-43
#
# 2_Random vs. 2_PLAID: t-test independent samples, P_val:4.380e-24 t=1.015e+01
# 2_PLAID vs. 2_COMPD: t-test independent samples, P_val:1.052e-01 t=-1.620e+00
# 3_Random vs. 3_PLAID: t-test independent samples, P_val:1.730e-73 t=1.837e+01
# 3_PLAID vs. 3_COMPD: t-test independent samples, P_val:3.949e-05 t=-4.113e+00
# 1_Random vs. 1_PLAID: t-test independent samples, P_val:2.808e-24 t=1.018e+01
# 1_PLAID vs. 1_COMPD: t-test independent samples, P_val:4.239e-14 t=7.559e+00
# 2_Random vs. 2_COMPD: t-test independent samples, P_val:6.178e-17 t=8.377e+00
# 3_Random vs. 3_COMPD: t-test independent samples, P_val:8.665e-50 t=1.496e+01
# 1_Random vs. 1_COMPD: t-test independent samples, P_val:1.541e-67 t=1.743e+01
# p-value annotation legend:
#       ns: 1.00e-04 < p <= 1.00e+00
#        *: 1.00e-12 < p <= 1.00e-04
# ...

# %%
# 12 doses (currently on the paper. Using 4 neg controls in the curve)
fig_name = "-12doses-dil4-bowl-neg-controls-0.085"
absolute_ic50_data_1rep = np.loadtxt(data_dir+'absolute_ic50_data-24-12-dil4-1-0.085-20250706-bowl-neg-control-new-reg.csv', delimiter=',', dtype='str')
absolute_ic50_data_2rep = np.loadtxt(data_dir+'absolute_ic50_data-12-12-dil4-2-0.085-20250706-bowl-neg-control-new-reg.csv', delimiter=',', dtype='str')
absolute_ic50_data_3rep = np.loadtxt(data_dir+'absolute_ic50_data-8-12-dil4-3-0.085-20250706-bowl-neg-control-new-reg.csv', delimiter=',', dtype='str')

util.generate_absic50_ddiff_tables(absolute_ic50_data_1rep, absolute_ic50_data_2rep, absolute_ic50_data_3rep, fig_name, figures_dir, tables_dir, y_max_absic,
y_max_d_diff,leg_ncol_d_diff,leg_loc_d_diff)
# Out:
# p-value annotation legend:
#       ns: 1.00e-04 < p <= 1.00e+00
#        *: 1.00e-12 < p <= 1.00e-04
#       **: 1.00e-43 < p <= 1.00e-12
#      ***: p <= 1.00e-43
#
# 2_Random vs. 2_PLAID: t-test independent samples, P_val:6.082e-20 t=9.163e+00
# 2_PLAID vs. 2_COMPD: t-test independent samples, P_val:8.833e-02 t=-1.704e+00
# 3_Random vs. 3_PLAID: t-test independent samples, P_val:2.574e-67 t=1.754e+01
# 3_PLAID vs. 3_COMPD: t-test independent samples, P_val:7.167e-05 t=-3.973e+00
# 1_Random vs. 1_PLAID: t-test independent samples, P_val:7.798e-18 t=8.611e+00
# 1_PLAID vs. 1_COMPD: t-test independent samples, P_val:6.616e-15 t=7.798e+00
# 2_Random vs. 2_COMPD: t-test independent samples, P_val:3.236e-13 t=7.294e+00
# 3_Random vs. 3_COMPD: t-test independent samples, P_val:3.912e-45 t=1.421e+01
# 1_Random vs. 1_COMPD: t-test independent samples, P_val:4.797e-60 t=1.640e+01
# p-value annotation legend:
#       ns: 1.00e-04 < p <= 1.00e+00
#        *: 1.00e-12 < p <= 1.00e-04
# ...

# %% [markdown]
# ## Half columns
#
# Figure 2 in the manuscript

# %%
# 8 doses (currently on the paper)
fig_name = "-8doses-dil8-right-half-neg-controls-0.4_paper"

absolute_ic50_data_1rep = np.loadtxt(data_dir+'absolute_ic50_data-36-8-dil8-1-0.4-20250706-log-neg-control-new-reg.csv', delimiter=',', dtype='str')
absolute_ic50_data_2rep = np.loadtxt(data_dir+'absolute_ic50_data-18-8-dil8-2-0.4-20250706-log-neg-control-new-reg.csv', delimiter=',', dtype='str')
absolute_ic50_data_3rep = np.loadtxt(data_dir+'absolute_ic50_data-12-8-dil8-3-0.4-20250706-log-neg-control-new-reg.csv', delimiter=',', dtype='str')

util.generate_absic50_ddiff_tables(absolute_ic50_data_1rep, absolute_ic50_data_2rep, absolute_ic50_data_3rep, fig_name, figures_dir, tables_dir, leg_ncol_d_diff=1,leg_loc_d_diff="upper right",
                                   y_max_d_diff = 14)
# Out:
# p-value annotation legend:
#       ns: 1.00e-04 < p <= 1.00e+00
#        *: 1.00e-12 < p <= 1.00e-04
#       **: 1.00e-43 < p <= 1.00e-12
#      ***: p <= 1.00e-43
#
# 2_Random vs. 2_PLAID: t-test independent samples, P_val:6.645e-58 t=1.611e+01
# 2_PLAID vs. 2_COMPD: t-test independent samples, P_val:1.979e-03 t=3.094e+00
# 3_Random vs. 3_PLAID: t-test independent samples, P_val:1.551e-72 t=1.817e+01
# 3_PLAID vs. 3_COMPD: t-test independent samples, P_val:5.574e-05 t=4.032e+00
# 1_Random vs. 1_PLAID: t-test independent samples, P_val:1.726e-57 t=1.602e+01
# 1_PLAID vs. 1_COMPD: t-test independent samples, P_val:2.993e-234 t=-3.299e+01
# 2_Random vs. 2_COMPD: t-test independent samples, P_val:1.195e-78 t=1.889e+01
# 3_Random vs. 3_COMPD: t-test independent samples, P_val:4.306e-103 t=2.182e+01
# 1_Random vs. 1_COMPD: t-test independent samples, P_val:9.478e-55 t=-1.562e+01
# p-value annotation legend:
#       ns: 1.00e-04 < p <= 1.00e+00
#        *: 1.00e-12 < p <= 1.00e-04
# ...

# %% [markdown]
# ## Half column (supplement)
#
# ### Weaker plate effect

# %%
## To get the same y axis in subplots in the same figure
y_max_absic = 0.3
y_max_d_diff = 14

leg_ncol_d_diff = 1
leg_loc_d_diff = "upper right"

# %%
# 6 doses (currently part of the supplement)
fig_name = "-6doses-dil18-half-columns-neg-controls-0.2"
absolute_ic50_data_1rep = np.loadtxt(data_dir+'absolute_ic50_data-48-6-dil18-1-0.2-20250706-right-half-neg-control-log-new-reg.csv', delimiter=',', dtype='str')
absolute_ic50_data_2rep = np.loadtxt(data_dir+'absolute_ic50_data-24-6-dil18-2-0.2-20250706-right-half-neg-control-log-new-reg.csv', delimiter=',', dtype='str')
absolute_ic50_data_3rep = np.loadtxt(data_dir+'absolute_ic50_data-16-6-dil18-3-0.2-20250706-right-half-neg-control-log-new-reg.csv', delimiter=',', dtype='str')

util.generate_absic50_ddiff_tables(absolute_ic50_data_1rep, absolute_ic50_data_2rep, absolute_ic50_data_3rep, fig_name, figures_dir, tables_dir, y_max_absic,
y_max_d_diff,leg_ncol_d_diff,leg_loc_d_diff)
# Out:
# p-value annotation legend:
#       ns: 1.00e-04 < p <= 1.00e+00
#        *: 1.00e-12 < p <= 1.00e-04
#       **: 1.00e-43 < p <= 1.00e-12
#      ***: p <= 1.00e-43
#
# 2_Random vs. 2_PLAID: t-test independent samples, P_val:4.586e-35 t=1.238e+01
# 2_PLAID vs. 2_COMPD: t-test independent samples, P_val:7.743e-02 t=1.766e+00
# 3_Random vs. 3_PLAID: t-test independent samples, P_val:1.317e-57 t=1.608e+01
# 3_PLAID vs. 3_COMPD: t-test independent samples, P_val:7.996e-02 t=-1.751e+00
# 1_Random vs. 1_PLAID: t-test independent samples, P_val:1.261e-45 t=1.420e+01
# 1_PLAID vs. 1_COMPD: t-test independent samples, P_val:6.873e-07 t=4.966e+00
# 2_Random vs. 2_COMPD: t-test independent samples, P_val:4.476e-44 t=1.396e+01
# 3_Random vs. 3_COMPD: t-test independent samples, P_val:8.695e-50 t=1.490e+01
# 1_Random vs. 1_COMPD: t-test independent samples, P_val:4.452e-78 t=1.875e+01
# p-value annotation legend:
#       ns: 1.00e-04 < p <= 1.00e+00
#        *: 1.00e-12 < p <= 1.00e-04
# ...

# %%
# 8 doses (currently part of the supplement)
fig_name = "-8doses-dil8-half-columns-neg-controls-0.2"
absolute_ic50_data_1rep = np.loadtxt(data_dir+'absolute_ic50_data-36-8-dil8-1-0.2-20250706-right-half-neg-control-log-new-reg.csv', delimiter=',', dtype='str')
absolute_ic50_data_2rep = np.loadtxt(data_dir+'absolute_ic50_data-18-8-dil8-2-0.2-20250706-right-half-neg-control-log-new-reg.csv', delimiter=',', dtype='str')
absolute_ic50_data_3rep = np.loadtxt(data_dir+'absolute_ic50_data-12-8-dil8-3-0.2-20250706-right-half-neg-control-log-new-reg.csv', delimiter=',', dtype='str')

util.generate_absic50_ddiff_tables(absolute_ic50_data_1rep, absolute_ic50_data_2rep, absolute_ic50_data_3rep, fig_name, figures_dir, tables_dir, y_max_absic,
y_max_d_diff,leg_ncol_d_diff,leg_loc_d_diff)
# Out:
# p-value annotation legend:
#       ns: 1.00e-04 < p <= 1.00e+00
#        *: 1.00e-12 < p <= 1.00e-04
#       **: 1.00e-43 < p <= 1.00e-12
#      ***: p <= 1.00e-43
#
# 2_Random vs. 2_PLAID: t-test independent samples, P_val:1.248e-55 t=1.578e+01
# 2_PLAID vs. 2_COMPD: t-test independent samples, P_val:9.098e-01 t=-1.134e-01
# 3_Random vs. 3_PLAID: t-test independent samples, P_val:2.271e-77 t=1.879e+01
# 3_PLAID vs. 3_COMPD: t-test independent samples, P_val:1.720e-03 t=3.136e+00
# 1_Random vs. 1_PLAID: t-test independent samples, P_val:5.357e-53 t=1.535e+01
# 1_PLAID vs. 1_COMPD: t-test independent samples, P_val:1.657e-279 t=-3.612e+01
# 2_Random vs. 2_COMPD: t-test independent samples, P_val:9.849e-57 t=1.594e+01
# 3_Random vs. 3_COMPD: t-test independent samples, P_val:5.322e-98 t=2.125e+01
# 1_Random vs. 1_COMPD: t-test independent samples, P_val:4.606e-64 t=-1.694e+01
# p-value annotation legend:
#       ns: 1.00e-04 < p <= 1.00e+00
#        *: 1.00e-12 < p <= 1.00e-04
# ...

# %%
# 12 doses (currently part of the supplement)
fig_name = "-12doses-dil4-half-columns-neg-controls-0.2"
absolute_ic50_data_1rep = np.loadtxt(data_dir+'absolute_ic50_data-24-12-dil4-1-0.2-20250706-right-half-neg-control-log-new-reg.csv', delimiter=',', dtype='str')
absolute_ic50_data_2rep = np.loadtxt(data_dir+'absolute_ic50_data-12-12-dil4-2-0.2-20250706-right-half-neg-control-log-new-reg.csv', delimiter=',', dtype='str')
absolute_ic50_data_3rep = np.loadtxt(data_dir+'absolute_ic50_data-8-12-dil4-3-0.2-20250706-right-half-neg-control-log-new-reg.csv', delimiter=',', dtype='str')

util.generate_absic50_ddiff_tables(absolute_ic50_data_1rep, absolute_ic50_data_2rep, absolute_ic50_data_3rep, fig_name, figures_dir, tables_dir, y_max_absic,
y_max_d_diff,leg_ncol_d_diff,leg_loc_d_diff)
# Out:
# p-value annotation legend:
#       ns: 1.00e-04 < p <= 1.00e+00
#        *: 1.00e-12 < p <= 1.00e-04
#       **: 1.00e-43 < p <= 1.00e-12
#      ***: p <= 1.00e-43
#
# 2_Random vs. 2_PLAID: t-test independent samples, P_val:8.268e-98 t=2.123e+01
# 2_PLAID vs. 2_COMPD: t-test independent samples, P_val:1.692e-02 t=-2.389e+00
# 3_Random vs. 3_PLAID: t-test independent samples, P_val:1.932e-63 t=1.700e+01
# 3_PLAID vs. 3_COMPD: t-test independent samples, P_val:5.881e-03 t=2.755e+00
# 1_Random vs. 1_PLAID: t-test independent samples, P_val:3.697e-120 t=2.347e+01
# 1_PLAID vs. 1_COMPD: t-test independent samples, P_val:4.191e-24 t=-1.014e+01
# 2_Random vs. 2_COMPD: t-test independent samples, P_val:1.351e-89 t=2.028e+01
# 3_Random vs. 3_COMPD: t-test independent samples, P_val:6.711e-79 t=1.907e+01
# 1_Random vs. 1_COMPD: t-test independent samples, P_val:2.186e-54 t=1.558e+01
# p-value annotation legend:
#       ns: 1.00e-04 < p <= 1.00e+00
#        *: 1.00e-12 < p <= 1.00e-04
# ...

# %% [markdown]
# ### Stronger plate effect

# %%
# 6 doses (currently part of the supplement)
fig_name = "-6doses-dil18-half-columns-neg-controls-0.4"
absolute_ic50_data_1rep = np.loadtxt(data_dir+'absolute_ic50_data-48-6-dil18-1-0.4-20250706-right-half-neg-control-log-new-reg.csv', delimiter=',', dtype='str')
absolute_ic50_data_2rep = np.loadtxt(data_dir+'absolute_ic50_data-24-6-dil18-2-0.4-20250706-right-half-neg-control-log-new-reg.csv', delimiter=',', dtype='str')
absolute_ic50_data_3rep = np.loadtxt(data_dir+'absolute_ic50_data-16-6-dil18-3-0.4-20250706-right-half-neg-control-log-new-reg.csv', delimiter=',', dtype='str')

util.generate_absic50_ddiff_tables(absolute_ic50_data_1rep, absolute_ic50_data_2rep, absolute_ic50_data_3rep, fig_name, figures_dir, tables_dir, y_max_absic,
y_max_d_diff,leg_ncol_d_diff,leg_loc_d_diff)

## 3 replicates
util.create_latex_table_wide(absolute_ic50_data_1rep, absolute_ic50_data_2rep, absolute_ic50_data_3rep, tables_dir+"absic50-table"+fig_name+".tex", table_text = "Absolute \\ECIC{}", column_name="MSE")
util.create_latex_table_pvalues_wide(absolute_ic50_data_1rep, absolute_ic50_data_2rep, absolute_ic50_data_3rep, tables_dir+"pvalues-absic50-table"+fig_name+".tex", table_text = "Absolute \\ECIC{}", column_name="MSE")
# Out:
# p-value annotation legend:
#       ns: 1.00e-04 < p <= 1.00e+00
#        *: 1.00e-12 < p <= 1.00e-04
#       **: 1.00e-43 < p <= 1.00e-12
#      ***: p <= 1.00e-43
#
# 2_Random vs. 2_PLAID: t-test independent samples, P_val:1.437e-32 t=1.191e+01
# 2_PLAID vs. 2_COMPD: t-test independent samples, P_val:1.024e-05 t=4.413e+00
# 3_Random vs. 3_PLAID: t-test independent samples, P_val:7.672e-62 t=1.668e+01
# 3_PLAID vs. 3_COMPD: t-test independent samples, P_val:3.255e-01 t=-9.833e-01
# 1_Random vs. 1_PLAID: t-test independent samples, P_val:1.527e-59 t=1.630e+01
# 1_PLAID vs. 1_COMPD: t-test independent samples, P_val:9.782e-01 t=2.730e-02
# 2_Random vs. 2_COMPD: t-test independent samples, P_val:2.112e-55 t=1.573e+01
# 3_Random vs. 3_COMPD: t-test independent samples, P_val:1.027e-58 t=1.624e+01
# 1_Random vs. 1_COMPD: t-test independent samples, P_val:9.930e-63 t=1.675e+01
# p-value annotation legend:
#       ns: 1.00e-04 < p <= 1.00e+00
#        *: 1.00e-12 < p <= 1.00e-04
# ...

# %%
# 8 doses (currently part of the paper)
fig_name = "-8doses-dil8-half-columns-neg-controls-0.4"

absolute_ic50_data_1rep = np.loadtxt(data_dir+'absolute_ic50_data-36-8-dil8-1-0.4-20250706-right-half-neg-control-log-new-reg.csv', delimiter=',', dtype='str')
absolute_ic50_data_2rep = np.loadtxt(data_dir+'absolute_ic50_data-18-8-dil8-2-0.4-20250706-right-half-neg-control-log-new-reg.csv', delimiter=',', dtype='str')
absolute_ic50_data_3rep = np.loadtxt(data_dir+'absolute_ic50_data-12-8-dil8-3-0.4-20250706-right-half-neg-control-log-new-reg.csv', delimiter=',', dtype='str')

util.generate_absic50_ddiff_tables(absolute_ic50_data_1rep, absolute_ic50_data_2rep, absolute_ic50_data_3rep, fig_name, figures_dir, tables_dir, y_max_absic,
y_max_d_diff,leg_ncol_d_diff,leg_loc_d_diff)

## 3 replicates
util.create_latex_table_wide(absolute_ic50_data_1rep, absolute_ic50_data_2rep, absolute_ic50_data_3rep, tables_dir+"absic50-table"+fig_name+".tex", table_text = "Absolute \\ECIC{}", column_name="MSE")
util.create_latex_table_pvalues_wide(absolute_ic50_data_1rep, absolute_ic50_data_2rep, absolute_ic50_data_3rep, tables_dir+"pvalues-absic50-table"+fig_name+".tex", table_text = "Absolute \\ECIC{}", column_name="MSE")
# Out:
# p-value annotation legend:
#       ns: 1.00e-04 < p <= 1.00e+00
#        *: 1.00e-12 < p <= 1.00e-04
#       **: 1.00e-43 < p <= 1.00e-12
#      ***: p <= 1.00e-43
#
# 2_Random vs. 2_PLAID: t-test independent samples, P_val:1.130e-57 t=1.608e+01
# 2_PLAID vs. 2_COMPD: t-test independent samples, P_val:1.043e-02 t=2.562e+00
# 3_Random vs. 3_PLAID: t-test independent samples, P_val:4.238e-72 t=1.811e+01
# 3_PLAID vs. 3_COMPD: t-test independent samples, P_val:3.716e-05 t=4.126e+00
# 1_Random vs. 1_PLAID: t-test independent samples, P_val:3.064e-57 t=1.598e+01
# 1_PLAID vs. 1_COMPD: t-test independent samples, P_val:2.799e-231 t=-3.277e+01
# 2_Random vs. 2_COMPD: t-test independent samples, P_val:1.171e-74 t=1.839e+01
# 3_Random vs. 3_COMPD: t-test independent samples, P_val:2.187e-103 t=2.186e+01
# 1_Random vs. 1_COMPD: t-test independent samples, P_val:1.048e-53 t=-1.546e+01
# p-value annotation legend:
#       ns: 1.00e-04 < p <= 1.00e+00
#        *: 1.00e-12 < p <= 1.00e-04
# ...

# %%
# 12 doses (part of the supplement)
fig_name = "-12doses-dil4-half-columns-neg-controls-0.4"
absolute_ic50_data_1rep = np.loadtxt(data_dir+'absolute_ic50_data-24-12-dil4-1-0.4-20250706-right-half-neg-control-log-new-reg.csv', delimiter=',', dtype='str')
absolute_ic50_data_2rep = np.loadtxt(data_dir+'absolute_ic50_data-12-12-dil4-2-0.4-20250706-right-half-neg-control-log-new-reg.csv', delimiter=',', dtype='str')
absolute_ic50_data_3rep = np.loadtxt(data_dir+'absolute_ic50_data-8-12-dil4-3-0.4-20250706-right-half-neg-control-log-new-reg.csv', delimiter=',', dtype='str')

util.generate_absic50_ddiff_tables(absolute_ic50_data_1rep, absolute_ic50_data_2rep, absolute_ic50_data_3rep, fig_name, figures_dir, tables_dir, y_max_absic,
y_max_d_diff,leg_ncol_d_diff,leg_loc_d_diff)
# Out:
# p-value annotation legend:
#       ns: 1.00e-04 < p <= 1.00e+00
#        *: 1.00e-12 < p <= 1.00e-04
#       **: 1.00e-43 < p <= 1.00e-12
#      ***: p <= 1.00e-43
#
# 2_Random vs. 2_PLAID: t-test independent samples, P_val:6.990e-94 t=2.078e+01
# 2_PLAID vs. 2_COMPD: t-test independent samples, P_val:6.160e-01 t=-5.015e-01
# 3_Random vs. 3_PLAID: t-test independent samples, P_val:5.506e-66 t=1.736e+01
# 3_PLAID vs. 3_COMPD: t-test independent samples, P_val:1.043e-06 t=4.888e+00
# 1_Random vs. 1_PLAID: t-test independent samples, P_val:2.388e-134 t=2.486e+01
# 1_PLAID vs. 1_COMPD: t-test independent samples, P_val:6.400e-17 t=-8.365e+00
# 2_Random vs. 2_COMPD: t-test independent samples, P_val:4.926e-99 t=2.137e+01
# 3_Random vs. 3_COMPD: t-test independent samples, P_val:1.216e-97 t=2.134e+01
# 1_Random vs. 1_COMPD: t-test independent samples, P_val:7.708e-73 t=1.813e+01
# p-value annotation legend:
#       ns: 1.00e-04 < p <= 1.00e+00
#        *: 1.00e-12 < p <= 1.00e-04
# ...

# %%
# 12 doses (another simulation, similar results)
fig_name = "-12doses-dil4-half-columns-neg-controls-0.4-b"
absolute_ic50_data_1rep = np.loadtxt(data_dir+'absolute_ic50_data-24-12-dil4-1-0.4-20250706-log-neg-control-new-reg.csv', delimiter=',', dtype='str')
absolute_ic50_data_2rep = np.loadtxt(data_dir+'absolute_ic50_data-12-12-dil4-2-0.4-20250706-log-neg-control-new-reg.csv', delimiter=',', dtype='str')
absolute_ic50_data_3rep = np.loadtxt(data_dir+'absolute_ic50_data-8-12-dil4-3-0.4-20250706-log-neg-control-new-reg.csv', delimiter=',', dtype='str')

util.generate_absic50_ddiff_tables(absolute_ic50_data_1rep, absolute_ic50_data_2rep, absolute_ic50_data_3rep, fig_name, figures_dir, tables_dir, y_max_absic,
y_max_d_diff,leg_ncol_d_diff,leg_loc_d_diff)
# Out:
# p-value annotation legend:
#       ns: 1.00e-04 < p <= 1.00e+00
#        *: 1.00e-12 < p <= 1.00e-04
#       **: 1.00e-43 < p <= 1.00e-12
#      ***: p <= 1.00e-43
#
# 2_Random vs. 2_PLAID: t-test independent samples, P_val:1.466e-92 t=2.063e+01
# 2_PLAID vs. 2_COMPD: t-test independent samples, P_val:7.267e-01 t=-3.495e-01
# 3_Random vs. 3_PLAID: t-test independent samples, P_val:1.100e-66 t=1.745e+01
# 3_PLAID vs. 3_COMPD: t-test independent samples, P_val:1.282e-06 t=4.847e+00
# 1_Random vs. 1_PLAID: t-test independent samples, P_val:2.788e-135 t=2.495e+01
# 1_PLAID vs. 1_COMPD: t-test independent samples, P_val:1.215e-16 t=-8.289e+00
# 2_Random vs. 2_COMPD: t-test independent samples, P_val:1.063e-98 t=2.133e+01
# 3_Random vs. 3_COMPD: t-test independent samples, P_val:3.305e-98 t=2.140e+01
# 1_Random vs. 1_COMPD: t-test independent samples, P_val:5.625e-74 t=1.827e+01
# p-value annotation legend:
#       ns: 1.00e-04 < p <= 1.00e+00
#        *: 1.00e-12 < p <= 1.00e-04
# ...

# %% [markdown]
# ## Plotting the relative EC50/IC50 and the percentage of low-quality curves
#
# Low-quality curves are those with $R^2<0.8$

# %%
y_max_relic = 0.6
y_max_r2 = 10

# %%
# 6 doses (currently on the appendix. Does not use neg controls, only compound points)
fig_name = "-6doses-dil18-bowl-0.055"

relative_ic50_data_1rep = np.loadtxt(data_dir+'relative_ic50_data-48-6-dil18-1-0.055-20250706-curve_info-new-reg.csv', delimiter=',', dtype='str')
relative_ic50_data_2rep = np.loadtxt(data_dir+'relative_ic50_data-24-6-dil18-2-0.055-20250706-curve_info-new-reg.csv', delimiter=',', dtype='str')
relative_ic50_data_3rep = np.loadtxt(data_dir+'relative_ic50_data-16-6-dil18-3-0.055-20250706-curve_info-new-reg.csv', delimiter=',', dtype='str')

util.generate_relic50_r2(relative_ic50_data_1rep, relative_ic50_data_2rep, relative_ic50_data_3rep, fig_name, figures_dir, y_max_relic = y_max_relic, y_max_r2 = y_max_r2)
# Out:
# p-value annotation legend:
#       ns: 1.00e-04 < p <= 1.00e+00
#        *: 1.00e-12 < p <= 1.00e-04
#       **: 1.00e-43 < p <= 1.00e-12
#      ***: p <= 1.00e-43
#
# 2_Random vs. 2_PLAID: t-test independent samples, P_val:4.540e-03 t=2.838e+00
# 2_PLAID vs. 2_COMPD: t-test independent samples, P_val:5.169e-01 t=-6.482e-01
# 3_Random vs. 3_PLAID: t-test independent samples, P_val:8.739e-32 t=1.176e+01
# 3_PLAID vs. 3_COMPD: t-test independent samples, P_val:3.522e-15 t=-7.881e+00
# 1_Random vs. 1_PLAID: t-test independent samples, P_val:1.116e-11 t=6.793e+00
# 1_PLAID vs. 1_COMPD: t-test independent samples, P_val:2.266e-09 t=5.979e+00
# 2_Random vs. 2_COMPD: t-test independent samples, P_val:2.539e-02 t=2.236e+00
# 3_Random vs. 3_COMPD: t-test independent samples, P_val:5.405e-05 t=4.039e+00
# 1_Random vs. 1_COMPD: t-test independent samples, P_val:1.461e-18 t=8.797e+00
# ...

# %%
# 6 doses (currently on the supplement. Does not use neg controls, only compound points)
fig_name = "-6doses-dil18-bowl-0.085"

relative_ic50_data_1rep = np.loadtxt(data_dir+'relative_ic50_data-48-6-dil18-1-0.085-20250706-curve_info-new-reg.csv', delimiter=',', dtype='str')
relative_ic50_data_2rep = np.loadtxt(data_dir+'relative_ic50_data-24-6-dil18-2-0.085-20250706-curve_info-new-reg.csv', delimiter=',', dtype='str')
relative_ic50_data_3rep = np.loadtxt(data_dir+'relative_ic50_data-16-6-dil18-3-0.085-20250706-curve_info-new-reg.csv', delimiter=',', dtype='str')

util.generate_relic50_r2(relative_ic50_data_1rep, relative_ic50_data_2rep, relative_ic50_data_3rep, fig_name, figures_dir, y_max_relic = y_max_relic, y_max_r2 = y_max_r2)
# Out:
# p-value annotation legend:
#       ns: 1.00e-04 < p <= 1.00e+00
#        *: 1.00e-12 < p <= 1.00e-04
#       **: 1.00e-43 < p <= 1.00e-12
#      ***: p <= 1.00e-43
#
# 2_Random vs. 2_PLAID: t-test independent samples, P_val:4.678e-02 t=1.988e+00
# 2_PLAID vs. 2_COMPD: t-test independent samples, P_val:4.463e-01 t=7.616e-01
# 3_Random vs. 3_PLAID: t-test independent samples, P_val:8.927e-34 t=1.215e+01
# 3_PLAID vs. 3_COMPD: t-test independent samples, P_val:8.869e-15 t=-7.764e+00
# 1_Random vs. 1_PLAID: t-test independent samples, P_val:1.719e-05 t=4.299e+00
# 1_PLAID vs. 1_COMPD: t-test independent samples, P_val:9.515e-02 t=1.669e+00
# 2_Random vs. 2_COMPD: t-test independent samples, P_val:3.942e-03 t=2.883e+00
# 3_Random vs. 3_COMPD: t-test independent samples, P_val:4.703e-06 t=4.580e+00
# 1_Random vs. 1_COMPD: t-test independent samples, P_val:3.300e-09 t=5.917e+00
# ...

# %%
# 8 doses (currently on the supplement. Does not use neg controls, only compound points)
fig_name = "-8doses-dil8-bowl-0.055"

relative_ic50_data_1rep = np.loadtxt(data_dir+'relative_ic50_data-36-8-dil8-1-0.055-20250706-curve_info-new-reg.csv', delimiter=',', dtype='str')
relative_ic50_data_2rep = np.loadtxt(data_dir+'relative_ic50_data-18-8-dil8-2-0.055-20250706-curve_info-new-reg.csv', delimiter=',', dtype='str')
relative_ic50_data_3rep = np.loadtxt(data_dir+'relative_ic50_data-12-8-dil8-3-0.055-20250706-curve_info-new-reg.csv', delimiter=',', dtype='str')

util.generate_relic50_r2(relative_ic50_data_1rep, relative_ic50_data_2rep, relative_ic50_data_3rep, fig_name, figures_dir, y_max_relic = y_max_relic, y_max_r2 = y_max_r2)
# Out:
# p-value annotation legend:
#       ns: 1.00e-04 < p <= 1.00e+00
#        *: 1.00e-12 < p <= 1.00e-04
#       **: 1.00e-43 < p <= 1.00e-12
#      ***: p <= 1.00e-43
#
# 2_Random vs. 2_PLAID: t-test independent samples, P_val:4.921e-02 t=-1.967e+00
# 2_PLAID vs. 2_COMPD: t-test independent samples, P_val:1.637e-06 t=4.796e+00
# 3_Random vs. 3_PLAID: t-test independent samples, P_val:8.880e-22 t=9.612e+00
# 3_PLAID vs. 3_COMPD: t-test independent samples, P_val:4.445e-02 t=-2.010e+00
# 1_Random vs. 1_PLAID: t-test independent samples, P_val:3.791e-01 t=8.796e-01
# 1_PLAID vs. 1_COMPD: t-test independent samples, P_val:9.693e-43 t=-1.373e+01
# 2_Random vs. 2_COMPD: t-test independent samples, P_val:2.697e-03 t=3.001e+00
# 3_Random vs. 3_COMPD: t-test independent samples, P_val:3.096e-13 t=7.300e+00
# 1_Random vs. 1_COMPD: t-test independent samples, P_val:4.210e-41 t=-1.345e+01
# ...

# %%
# 8 doses (currently on the appendix. Does not use neg controls, only compound points)
fig_name = "-8doses-dil8-bowl-0.085"
pvalue_thresholds = [[1e-43, "***"], [1e-12, "**"], [0.05, "*"], [1, "ns"]]

relative_ic50_data_1rep = np.loadtxt(data_dir+'relative_ic50_data-36-8-dil8-1-0.085-20250706-curve_info-new-reg.csv', delimiter=',', dtype='str')
relative_ic50_data_2rep = np.loadtxt(data_dir+'relative_ic50_data-18-8-dil8-2-0.085-20250706-curve_info-new-reg.csv', delimiter=',', dtype='str')
relative_ic50_data_3rep = np.loadtxt(data_dir+'relative_ic50_data-12-8-dil8-3-0.085-20250706-curve_info-new-reg.csv', delimiter=',', dtype='str')

util.generate_relic50_r2(relative_ic50_data_1rep, relative_ic50_data_2rep, relative_ic50_data_3rep, fig_name, figures_dir, y_max_relic = y_max_relic, y_max_r2 = y_max_r2, pvalue_thresholds=pvalue_thresholds)
# Out:
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-12 < p <= 5.00e-02
#       **: 1.00e-43 < p <= 1.00e-12
#      ***: p <= 1.00e-43
#
# 2_Random vs. 2_PLAID: t-test independent samples, P_val:4.222e-02 t=-2.032e+00
# 2_PLAID vs. 2_COMPD: t-test independent samples, P_val:5.351e-06 t=4.552e+00
# 3_Random vs. 3_PLAID: t-test independent samples, P_val:1.682e-23 t=1.002e+01
# 3_PLAID vs. 3_COMPD: t-test independent samples, P_val:6.199e-03 t=-2.738e+00
# 1_Random vs. 1_PLAID: t-test independent samples, P_val:1.572e-03 t=-3.161e+00
# 1_PLAID vs. 1_COMPD: t-test independent samples, P_val:1.100e-34 t=-1.230e+01
# 2_Random vs. 2_COMPD: t-test independent samples, P_val:4.052e-03 t=2.875e+00
# 3_Random vs. 3_COMPD: t-test independent samples, P_val:2.819e-11 t=6.664e+00
# 1_Random vs. 1_COMPD: t-test independent samples, P_val:4.140e-43 t=-1.379e+01
# ...

# %%
# 12 doses (currently on the appendix. Does not use neg controls, only compound points)
fig_name = "-12doses-dil4-bowl-0.055"
pvalue_thresholds = [[1e-43, "***"], [1e-12, "**"], [0.05, "*"], [1, "ns"]]

relative_ic50_data_1rep = np.loadtxt(data_dir+'relative_ic50_data-24-12-dil4-1-0.055-20250706-curve_info-new-reg.csv', delimiter=',', dtype='str')
relative_ic50_data_2rep = np.loadtxt(data_dir+'relative_ic50_data-12-12-dil4-2-0.055-20250706-curve_info-new-reg.csv', delimiter=',', dtype='str')
relative_ic50_data_3rep = np.loadtxt(data_dir+'relative_ic50_data-8-12-dil4-3-0.055-20250706-curve_info-new-reg.csv', delimiter=',', dtype='str')

util.generate_relic50_r2(relative_ic50_data_1rep, relative_ic50_data_2rep, relative_ic50_data_3rep, fig_name, figures_dir, y_max_relic = y_max_relic, y_max_r2 = y_max_r2, pvalue_thresholds=pvalue_thresholds)
# Out:
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-12 < p <= 5.00e-02
#       **: 1.00e-43 < p <= 1.00e-12
#      ***: p <= 1.00e-43
#
# 2_Random vs. 2_PLAID: t-test independent samples, P_val:2.675e-01 t=-1.109e+00
# 2_PLAID vs. 2_COMPD: t-test independent samples, P_val:8.012e-01 t=2.518e-01
# 3_Random vs. 3_PLAID: t-test independent samples, P_val:7.138e-06 t=4.493e+00
# 3_PLAID vs. 3_COMPD: t-test independent samples, P_val:3.366e-01 t=-9.610e-01
# 1_Random vs. 1_PLAID: t-test independent samples, P_val:2.931e-09 t=5.938e+00
# 1_PLAID vs. 1_COMPD: t-test independent samples, P_val:2.874e-10 t=6.309e+00
# 2_Random vs. 2_COMPD: t-test independent samples, P_val:3.849e-01 t=-8.689e-01
# 3_Random vs. 3_COMPD: t-test independent samples, P_val:1.418e-04 t=3.807e+00
# 1_Random vs. 1_COMPD: t-test independent samples, P_val:7.506e-32 t=1.177e+01
# ...

# %%
# 12 doses (currently on the appendix. Does not use neg controls, only compound points)
fig_name = "-12doses-dil4-bowl-0.085"
pvalue_thresholds = [[1e-43, "***"], [1e-12, "**"], [0.05, "*"], [1, "ns"]]

relative_ic50_data_1rep = np.loadtxt(data_dir+'relative_ic50_data-24-12-dil4-1-0.085-20250706-curve_info-new-reg.csv', delimiter=',', dtype='str')
relative_ic50_data_2rep = np.loadtxt(data_dir+'relative_ic50_data-12-12-dil4-2-0.085-20250706-curve_info-new-reg.csv', delimiter=',', dtype='str')
relative_ic50_data_3rep = np.loadtxt(data_dir+'relative_ic50_data-8-12-dil4-3-0.085-20250706-curve_info-new-reg.csv', delimiter=',', dtype='str')

util.generate_relic50_r2(relative_ic50_data_1rep, relative_ic50_data_2rep, relative_ic50_data_3rep, fig_name, figures_dir, y_max_relic = y_max_relic, y_max_r2 = y_max_r2, pvalue_thresholds=pvalue_thresholds)
# Out:
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-12 < p <= 5.00e-02
#       **: 1.00e-43 < p <= 1.00e-12
#      ***: p <= 1.00e-43
#
# 2_Random vs. 2_PLAID: t-test independent samples, P_val:8.130e-02 t=-1.743e+00
# 2_PLAID vs. 2_COMPD: t-test independent samples, P_val:5.478e-01 t=6.011e-01
# 3_Random vs. 3_PLAID: t-test independent samples, P_val:4.011e-05 t=4.110e+00
# 3_PLAID vs. 3_COMPD: t-test independent samples, P_val:4.253e-01 t=-7.973e-01
# 1_Random vs. 1_PLAID: t-test independent samples, P_val:5.160e-09 t=5.845e+00
# 1_PLAID vs. 1_COMPD: t-test independent samples, P_val:1.551e-06 t=4.806e+00
# 2_Random vs. 2_COMPD: t-test independent samples, P_val:2.361e-01 t=-1.185e+00
# 3_Random vs. 3_COMPD: t-test independent samples, P_val:3.393e-04 t=3.585e+00
# 1_Random vs. 1_COMPD: t-test independent samples, P_val:1.108e-23 t=1.004e+01
# ...

# %% [markdown]
# ### Bowl-shaped effect, using negative controls when estimating the curves

# %%
y_max_relic = 0.8
y_max_r2 = 10

# %%
# 6 doses (currently on the supplement. Using 4 negative controls)
fig_name = "-6doses-dil18-bowl-neg-controls-0.055"

relative_ic50_data_1rep = np.loadtxt(data_dir+'relative_ic50_data-48-6-dil18-1-0.055-20250706-bowl-neg-control-new-reg.csv', delimiter=',', dtype='str')
relative_ic50_data_2rep = np.loadtxt(data_dir+'relative_ic50_data-24-6-dil18-2-0.055-20250706-bowl-neg-control-new-reg.csv', delimiter=',', dtype='str')
relative_ic50_data_3rep = np.loadtxt(data_dir+'relative_ic50_data-16-6-dil18-3-0.055-20250706-bowl-neg-control-new-reg.csv', delimiter=',', dtype='str')

util.generate_relic50_r2(relative_ic50_data_1rep, relative_ic50_data_2rep, relative_ic50_data_3rep, fig_name, figures_dir, y_max_relic = y_max_relic, y_max_r2 = y_max_r2)
# Out:
# p-value annotation legend:
#       ns: 1.00e-04 < p <= 1.00e+00
#        *: 1.00e-12 < p <= 1.00e-04
#       **: 1.00e-43 < p <= 1.00e-12
#      ***: p <= 1.00e-43
#
# 2_Random vs. 2_PLAID: t-test independent samples, P_val:2.751e-03 t=2.995e+00
# 2_PLAID vs. 2_COMPD: t-test independent samples, P_val:2.977e-01 t=-1.041e+00
# 3_Random vs. 3_PLAID: t-test independent samples, P_val:1.300e-30 t=1.153e+01
# 3_PLAID vs. 3_COMPD: t-test independent samples, P_val:1.002e-14 t=-7.748e+00
# 1_Random vs. 1_PLAID: t-test independent samples, P_val:1.273e-11 t=6.774e+00
# 1_PLAID vs. 1_COMPD: t-test independent samples, P_val:6.587e-09 t=5.802e+00
# 2_Random vs. 2_COMPD: t-test independent samples, P_val:4.698e-02 t=1.987e+00
# 3_Random vs. 3_COMPD: t-test independent samples, P_val:1.014e-04 t=3.888e+00
# 1_Random vs. 1_COMPD: t-test independent samples, P_val:2.589e-18 t=8.733e+00
# ...

# %%
# 6 doses (currently on the supplement. Using 4 negative controls)
fig_name = "-6doses-dil18-bowl-neg-controls-0.085"

relative_ic50_data_1rep = np.loadtxt(data_dir+'relative_ic50_data-48-6-dil18-1-0.085-20250706-bowl-neg-control-new-reg.csv', delimiter=',', dtype='str')
relative_ic50_data_2rep = np.loadtxt(data_dir+'relative_ic50_data-24-6-dil18-2-0.085-20250706-bowl-neg-control-new-reg.csv', delimiter=',', dtype='str')
relative_ic50_data_3rep = np.loadtxt(data_dir+'relative_ic50_data-16-6-dil18-3-0.085-20250706-bowl-neg-control-new-reg.csv', delimiter=',', dtype='str')

util.generate_relic50_r2(relative_ic50_data_1rep, relative_ic50_data_2rep, relative_ic50_data_3rep, fig_name, figures_dir, y_max_relic = y_max_relic, y_max_r2 = y_max_r2)
# Out:
# p-value annotation legend:
#       ns: 1.00e-04 < p <= 1.00e+00
#        *: 1.00e-12 < p <= 1.00e-04
#       **: 1.00e-43 < p <= 1.00e-12
#      ***: p <= 1.00e-43
#
# 2_Random vs. 2_PLAID: t-test independent samples, P_val:4.510e-02 t=2.004e+00
# 2_PLAID vs. 2_COMPD: t-test independent samples, P_val:3.853e-01 t=8.682e-01
# 3_Random vs. 3_PLAID: t-test independent samples, P_val:1.267e-32 t=1.193e+01
# 3_PLAID vs. 3_COMPD: t-test independent samples, P_val:7.566e-15 t=-7.784e+00
# 1_Random vs. 1_PLAID: t-test independent samples, P_val:1.811e-05 t=4.288e+00
# 1_PLAID vs. 1_COMPD: t-test independent samples, P_val:1.526e-01 t=1.430e+00
# 2_Random vs. 2_COMPD: t-test independent samples, P_val:2.693e-03 t=3.001e+00
# 3_Random vs. 3_COMPD: t-test independent samples, P_val:1.294e-05 t=4.363e+00
# 1_Random vs. 1_COMPD: t-test independent samples, P_val:1.318e-08 t=5.685e+00
# ...

# %%
# 8 doses (currently on the appendix. Using 4 negative controls)
fig_name = "-8doses-dil8-bowl-neg-controls-0.055"
relative_ic50_data_1rep = np.loadtxt(data_dir+'relative_ic50_data-36-8-dil8-1-0.055-20250706-bowl-neg-control-new-reg.csv', delimiter=',', dtype='str')
relative_ic50_data_2rep = np.loadtxt(data_dir+'relative_ic50_data-18-8-dil8-2-0.055-20250706-bowl-neg-control-new-reg.csv', delimiter=',', dtype='str')
relative_ic50_data_3rep = np.loadtxt(data_dir+'relative_ic50_data-12-8-dil8-3-0.055-20250706-bowl-neg-control-new-reg.csv', delimiter=',', dtype='str')

util.generate_relic50_r2(relative_ic50_data_1rep, relative_ic50_data_2rep, relative_ic50_data_3rep, fig_name, figures_dir, y_max_relic = y_max_relic, y_max_r2 = y_max_r2)
# Out:
# p-value annotation legend:
#       ns: 1.00e-04 < p <= 1.00e+00
#        *: 1.00e-12 < p <= 1.00e-04
#       **: 1.00e-43 < p <= 1.00e-12
#      ***: p <= 1.00e-43
#
# 2_Random vs. 2_PLAID: t-test independent samples, P_val:7.281e-02 t=-1.794e+00
# 2_PLAID vs. 2_COMPD: t-test independent samples, P_val:2.566e-06 t=4.705e+00
# 3_Random vs. 3_PLAID: t-test independent samples, P_val:9.846e-21 t=9.359e+00
# 3_PLAID vs. 3_COMPD: t-test independent samples, P_val:1.264e-01 t=-1.529e+00
# 1_Random vs. 1_PLAID: t-test independent samples, P_val:3.209e-01 t=9.927e-01
# 1_PLAID vs. 1_COMPD: t-test independent samples, P_val:9.885e-43 t=-1.372e+01
# 2_Random vs. 2_COMPD: t-test independent samples, P_val:2.091e-03 t=3.078e+00
# 3_Random vs. 3_COMPD: t-test independent samples, P_val:6.899e-14 t=7.501e+00
# 1_Random vs. 1_COMPD: t-test independent samples, P_val:1.083e-40 t=-1.338e+01
# ...

# %%
# 8 doses (currently on the appendix. Using 4 negative controls)
fig_name = "-8doses-dil8-bowl-neg-controls-0.085"
relative_ic50_data_1rep = np.loadtxt(data_dir+'relative_ic50_data-36-8-dil8-1-0.085-20250706-bowl-neg-control-new-reg.csv', delimiter=',', dtype='str')
relative_ic50_data_2rep = np.loadtxt(data_dir+'relative_ic50_data-18-8-dil8-2-0.085-20250706-bowl-neg-control-new-reg.csv', delimiter=',', dtype='str')
relative_ic50_data_3rep = np.loadtxt(data_dir+'relative_ic50_data-12-8-dil8-3-0.085-20250706-bowl-neg-control-new-reg.csv', delimiter=',', dtype='str')

util.generate_relic50_r2(relative_ic50_data_1rep, relative_ic50_data_2rep, relative_ic50_data_3rep, fig_name, figures_dir, y_max_relic = y_max_relic, y_max_r2 = y_max_r2)
# Out:
# p-value annotation legend:
#       ns: 1.00e-04 < p <= 1.00e+00
#        *: 1.00e-12 < p <= 1.00e-04
#       **: 1.00e-43 < p <= 1.00e-12
#      ***: p <= 1.00e-43
#
# 2_Random vs. 2_PLAID: t-test independent samples, P_val:3.414e-02 t=-2.119e+00
# 2_PLAID vs. 2_COMPD: t-test independent samples, P_val:2.899e-06 t=4.680e+00
# 3_Random vs. 3_PLAID: t-test independent samples, P_val:3.119e-23 t=9.955e+00
# 3_PLAID vs. 3_COMPD: t-test independent samples, P_val:7.209e-03 t=-2.688e+00
# 1_Random vs. 1_PLAID: t-test independent samples, P_val:1.317e-03 t=-3.213e+00
# 1_PLAID vs. 1_COMPD: t-test independent samples, P_val:1.275e-34 t=-1.229e+01
# 2_Random vs. 2_COMPD: t-test independent samples, P_val:3.353e-03 t=2.934e+00
# 3_Random vs. 3_COMPD: t-test independent samples, P_val:2.478e-11 t=6.683e+00
# 1_Random vs. 1_COMPD: t-test independent samples, P_val:3.735e-43 t=-1.380e+01
# ...

# %%
# 12 doses (currently on the appendix. Using 4 negative controls)
fig_name = "-12doses-dil4-bowl-neg-controls-0.055"
relative_ic50_data_1rep = np.loadtxt(data_dir+'relative_ic50_data-24-12-dil4-1-0.055-20250706-bowl-neg-control-new-reg.csv', delimiter=',', dtype='str')
relative_ic50_data_2rep = np.loadtxt(data_dir+'relative_ic50_data-12-12-dil4-2-0.055-20250706-bowl-neg-control-new-reg.csv', delimiter=',', dtype='str')
relative_ic50_data_3rep = np.loadtxt(data_dir+'relative_ic50_data-8-12-dil4-3-0.055-20250706-bowl-neg-control-new-reg.csv', delimiter=',', dtype='str')

util.generate_relic50_r2(relative_ic50_data_1rep, relative_ic50_data_2rep, relative_ic50_data_3rep, fig_name, figures_dir, y_max_relic = y_max_relic, y_max_r2 = y_max_r2)
# Out:
# p-value annotation legend:
#       ns: 1.00e-04 < p <= 1.00e+00
#        *: 1.00e-12 < p <= 1.00e-04
#       **: 1.00e-43 < p <= 1.00e-12
#      ***: p <= 1.00e-43
#
# 2_Random vs. 2_PLAID: t-test independent samples, P_val:2.578e-01 t=-1.132e+00
# 2_PLAID vs. 2_COMPD: t-test independent samples, P_val:7.626e-01 t=3.020e-01
# 3_Random vs. 3_PLAID: t-test independent samples, P_val:8.052e-06 t=4.467e+00
# 3_PLAID vs. 3_COMPD: t-test independent samples, P_val:3.390e-01 t=-9.561e-01
# 1_Random vs. 1_PLAID: t-test independent samples, P_val:3.106e-09 t=5.929e+00
# 1_PLAID vs. 1_COMPD: t-test independent samples, P_val:1.225e-09 t=6.080e+00
# 2_Random vs. 2_COMPD: t-test independent samples, P_val:4.005e-01 t=-8.407e-01
# 3_Random vs. 3_COMPD: t-test independent samples, P_val:1.547e-04 t=3.786e+00
# 1_Random vs. 1_COMPD: t-test independent samples, P_val:9.528e-31 t=1.155e+01
# ...

# %%
# 12 doses (currently on the appendix. Using 4 negative controls)
fig_name = "-12doses-dil4-bowl-neg-controls-0.085"
relative_ic50_data_1rep = np.loadtxt(data_dir+'relative_ic50_data-24-12-dil4-1-0.085-20250706-bowl-neg-control-new-reg.csv', delimiter=',', dtype='str')
relative_ic50_data_2rep = np.loadtxt(data_dir+'relative_ic50_data-12-12-dil4-2-0.085-20250706-bowl-neg-control-new-reg.csv', delimiter=',', dtype='str')
relative_ic50_data_3rep = np.loadtxt(data_dir+'relative_ic50_data-8-12-dil4-3-0.085-20250706-bowl-neg-control-new-reg.csv', delimiter=',', dtype='str')

util.generate_relic50_r2(relative_ic50_data_1rep, relative_ic50_data_2rep, relative_ic50_data_3rep, fig_name, figures_dir, y_max_relic = y_max_relic, y_max_r2 = y_max_r2)
# Out:
# p-value annotation legend:
#       ns: 1.00e-04 < p <= 1.00e+00
#        *: 1.00e-12 < p <= 1.00e-04
#       **: 1.00e-43 < p <= 1.00e-12
#      ***: p <= 1.00e-43
#
# 2_Random vs. 2_PLAID: t-test independent samples, P_val:1.016e-01 t=-1.637e+00
# 2_PLAID vs. 2_COMPD: t-test independent samples, P_val:6.149e-01 t=5.031e-01
# 3_Random vs. 3_PLAID: t-test independent samples, P_val:6.363e-05 t=4.002e+00
# 3_PLAID vs. 3_COMPD: t-test independent samples, P_val:4.128e-01 t=-8.190e-01
# 1_Random vs. 1_PLAID: t-test independent samples, P_val:3.583e-09 t=5.905e+00
# 1_PLAID vs. 1_COMPD: t-test independent samples, P_val:6.372e-07 t=4.981e+00
# 2_Random vs. 2_COMPD: t-test independent samples, P_val:2.408e-01 t=-1.173e+00
# 3_Random vs. 3_COMPD: t-test independent samples, P_val:5.647e-04 t=3.450e+00
# 1_Random vs. 1_COMPD: t-test independent samples, P_val:1.217e-24 t=1.026e+01
# ...

# %% [markdown]
# ## Half Columns
#
# ### Weaker plate effects

# %%
y_max_relic = 0.5
y_max_r2 = 10

# %%
# 6 doses (part of the supplement)
fig_name = "-6doses-dil18-half-columns-neg-controls-0.2"
relative_ic50_data_1rep = np.loadtxt(data_dir+'relative_ic50_data-48-6-dil18-1-0.2-20250706-right-half-neg-control-log-new-reg.csv', delimiter=',', dtype='str')
relative_ic50_data_2rep = np.loadtxt(data_dir+'relative_ic50_data-24-6-dil18-2-0.2-20250706-right-half-neg-control-log-new-reg.csv', delimiter=',', dtype='str')
relative_ic50_data_3rep = np.loadtxt(data_dir+'relative_ic50_data-16-6-dil18-3-0.2-20250706-right-half-neg-control-log-new-reg.csv', delimiter=',', dtype='str')

util.generate_relic50_r2(relative_ic50_data_1rep, relative_ic50_data_2rep, relative_ic50_data_3rep, fig_name, figures_dir, y_max_relic = y_max_relic, y_max_r2 = y_max_r2)
# Out:
# p-value annotation legend:
#       ns: 1.00e-04 < p <= 1.00e+00
#        *: 1.00e-12 < p <= 1.00e-04
#       **: 1.00e-43 < p <= 1.00e-12
#      ***: p <= 1.00e-43
#
# 2_Random vs. 2_PLAID: t-test independent samples, P_val:1.760e-06 t=4.781e+00
# 2_PLAID vs. 2_COMPD: t-test independent samples, P_val:6.319e-01 t=4.790e-01
# 3_Random vs. 3_PLAID: t-test independent samples, P_val:7.936e-20 t=9.129e+00
# 3_PLAID vs. 3_COMPD: t-test independent samples, P_val:9.649e-01 t=4.398e-02
# 1_Random vs. 1_PLAID: t-test independent samples, P_val:1.478e-05 t=4.333e+00
# 1_PLAID vs. 1_COMPD: t-test independent samples, P_val:1.177e-04 t=3.851e+00
# 2_Random vs. 2_COMPD: t-test independent samples, P_val:7.363e-09 t=5.785e+00
# 3_Random vs. 3_COMPD: t-test independent samples, P_val:9.777e-21 t=9.355e+00
# 1_Random vs. 1_COMPD: t-test independent samples, P_val:3.249e-16 t=8.167e+00
# ...

# %%
# 8 doses (part of the supplement)
fig_name = "-8doses-dil8-half-columns-neg-controls-0.2"
relative_ic50_data_1rep = np.loadtxt(data_dir+'relative_ic50_data-36-8-dil8-1-0.2-20250706-right-half-neg-control-log-new-reg.csv', delimiter=',', dtype='str')
relative_ic50_data_2rep = np.loadtxt(data_dir+'relative_ic50_data-18-8-dil8-2-0.2-20250706-right-half-neg-control-log-new-reg.csv', delimiter=',', dtype='str')
relative_ic50_data_3rep = np.loadtxt(data_dir+'relative_ic50_data-12-8-dil8-3-0.2-20250706-right-half-neg-control-log-new-reg.csv', delimiter=',', dtype='str')

util.generate_relic50_r2(relative_ic50_data_1rep, relative_ic50_data_2rep, relative_ic50_data_3rep, fig_name, figures_dir, y_max_relic = y_max_relic, y_max_r2 = y_max_r2)
# Out:
# p-value annotation legend:
#       ns: 1.00e-04 < p <= 1.00e+00
#        *: 1.00e-12 < p <= 1.00e-04
#       **: 1.00e-43 < p <= 1.00e-12
#      ***: p <= 1.00e-43
#
# 2_Random vs. 2_PLAID: t-test independent samples, P_val:1.148e-12 t=7.118e+00
# 2_PLAID vs. 2_COMPD: t-test independent samples, P_val:8.751e-22 t=-9.606e+00
# 3_Random vs. 3_PLAID: t-test independent samples, P_val:5.434e-36 t=1.258e+01
# 3_PLAID vs. 3_COMPD: t-test independent samples, P_val:1.232e-15 t=8.015e+00
# 1_Random vs. 1_PLAID: t-test independent samples, P_val:5.712e-22 t=9.642e+00
# 1_PLAID vs. 1_COMPD: t-test independent samples, P_val:9.373e-124 t=-2.378e+01
# 2_Random vs. 2_COMPD: t-test independent samples, P_val:5.561e-02 t=-1.914e+00
# 3_Random vs. 3_COMPD: t-test independent samples, P_val:1.587e-83 t=1.955e+01
# 1_Random vs. 1_COMPD: t-test independent samples, P_val:6.875e-01 t=-4.022e-01
# ...

# %%
# 12 doses (part of the supplement)
fig_name = "-12doses-dil4-half-columns-neg-controls-0.2"
relative_ic50_data_1rep = np.loadtxt(data_dir+'relative_ic50_data-24-12-dil4-1-0.2-20250706-right-half-neg-control-log-new-reg.csv', delimiter=',', dtype='str')
relative_ic50_data_2rep = np.loadtxt(data_dir+'relative_ic50_data-12-12-dil4-2-0.2-20250706-right-half-neg-control-log-new-reg.csv', delimiter=',', dtype='str')
relative_ic50_data_3rep = np.loadtxt(data_dir+'relative_ic50_data-8-12-dil4-3-0.2-20250706-right-half-neg-control-log-new-reg.csv', delimiter=',', dtype='str')

util.generate_relic50_r2(relative_ic50_data_1rep, relative_ic50_data_2rep, relative_ic50_data_3rep, fig_name, figures_dir, y_max_relic = y_max_relic, y_max_r2 = y_max_r2)
# Out:
# p-value annotation legend:
#       ns: 1.00e-04 < p <= 1.00e+00
#        *: 1.00e-12 < p <= 1.00e-04
#       **: 1.00e-43 < p <= 1.00e-12
#      ***: p <= 1.00e-43
#
# 2_Random vs. 2_PLAID: t-test independent samples, P_val:6.893e-09 t=5.799e+00
# 2_PLAID vs. 2_COMPD: t-test independent samples, P_val:1.874e-03 t=-3.110e+00
# 3_Random vs. 3_PLAID: t-test independent samples, P_val:5.469e-06 t=4.550e+00
# 3_PLAID vs. 3_COMPD: t-test independent samples, P_val:7.527e-01 t=3.151e-01
# 1_Random vs. 1_PLAID: t-test independent samples, P_val:2.095e-23 t=9.981e+00
# 1_PLAID vs. 1_COMPD: t-test independent samples, P_val:1.571e-45 t=-1.420e+01
# 2_Random vs. 2_COMPD: t-test independent samples, P_val:7.095e-03 t=2.693e+00
# 3_Random vs. 3_COMPD: t-test independent samples, P_val:4.685e-06 t=4.582e+00
# 1_Random vs. 1_COMPD: t-test independent samples, P_val:1.738e-04 t=-3.755e+00
# ...

# %% [markdown]
# ### Stronger plate effects

# %%
# 6 doses (part of the supplement)
fig_name = "-6doses-dil18-half-columns-neg-controls-0.4"
relative_ic50_data_1rep = np.loadtxt(data_dir+'relative_ic50_data-48-6-dil18-1-0.4-20250706-right-half-neg-control-log-new-reg.csv', delimiter=',', dtype='str')
relative_ic50_data_2rep = np.loadtxt(data_dir+'relative_ic50_data-24-6-dil18-2-0.4-20250706-right-half-neg-control-log-new-reg.csv', delimiter=',', dtype='str')
relative_ic50_data_3rep = np.loadtxt(data_dir+'relative_ic50_data-16-6-dil18-3-0.4-20250706-right-half-neg-control-log-new-reg.csv', delimiter=',', dtype='str')

util.generate_relic50_r2(relative_ic50_data_1rep, relative_ic50_data_2rep, relative_ic50_data_3rep, fig_name, figures_dir, y_max_relic = y_max_relic, y_max_r2 = y_max_r2)
# Out:
# p-value annotation legend:
#       ns: 1.00e-04 < p <= 1.00e+00
#        *: 1.00e-12 < p <= 1.00e-04
#       **: 1.00e-43 < p <= 1.00e-12
#      ***: p <= 1.00e-43
#
# 2_Random vs. 2_PLAID: t-test independent samples, P_val:4.364e-01 t=7.782e-01
# 2_PLAID vs. 2_COMPD: t-test independent samples, P_val:2.401e-07 t=5.167e+00
# 3_Random vs. 3_PLAID: t-test independent samples, P_val:6.913e-07 t=4.966e+00
# 3_PLAID vs. 3_COMPD: t-test independent samples, P_val:2.671e-04 t=3.646e+00
# 1_Random vs. 1_PLAID: t-test independent samples, P_val:3.521e-19 t=8.956e+00
# 1_PLAID vs. 1_COMPD: t-test independent samples, P_val:4.153e-04 t=3.530e+00
# 2_Random vs. 2_COMPD: t-test independent samples, P_val:3.073e-10 t=6.298e+00
# 3_Random vs. 3_COMPD: t-test independent samples, P_val:3.662e-09 t=5.903e+00
# 1_Random vs. 1_COMPD: t-test independent samples, P_val:1.023e-34 t=1.230e+01
# ...

# %%
# 8 doses (part of the supplement)
fig_name = "-8doses-dil8-half-columns-neg-controls-0.4"
relative_ic50_data_1rep = np.loadtxt(data_dir+'relative_ic50_data-36-8-dil8-1-0.4-20250706-right-half-neg-control-log-new-reg.csv', delimiter=',', dtype='str')
relative_ic50_data_2rep = np.loadtxt(data_dir+'relative_ic50_data-18-8-dil8-2-0.4-20250706-right-half-neg-control-log-new-reg.csv', delimiter=',', dtype='str')
relative_ic50_data_3rep = np.loadtxt(data_dir+'relative_ic50_data-12-8-dil8-3-0.4-20250706-right-half-neg-control-log-new-reg.csv', delimiter=',', dtype='str')

util.generate_relic50_r2(relative_ic50_data_1rep, relative_ic50_data_2rep, relative_ic50_data_3rep, fig_name, figures_dir, y_max_relic = y_max_relic, y_max_r2 = y_max_r2)
# Out:
# p-value annotation legend:
#       ns: 1.00e-04 < p <= 1.00e+00
#        *: 1.00e-12 < p <= 1.00e-04
#       **: 1.00e-43 < p <= 1.00e-12
#      ***: p <= 1.00e-43
#
# 2_Random vs. 2_PLAID: t-test independent samples, P_val:2.658e-10 t=6.322e+00
# 2_PLAID vs. 2_COMPD: t-test independent samples, P_val:8.964e-20 t=-9.114e+00
# 3_Random vs. 3_PLAID: t-test independent samples, P_val:6.319e-28 t=1.099e+01
# 3_PLAID vs. 3_COMPD: t-test independent samples, P_val:2.184e-24 t=1.022e+01
# 1_Random vs. 1_PLAID: t-test independent samples, P_val:4.881e-25 t=1.034e+01
# 1_PLAID vs. 1_COMPD: t-test independent samples, P_val:3.197e-06 t=-4.659e+00
# 2_Random vs. 2_COMPD: t-test independent samples, P_val:8.185e-04 t=3.347e+00
# 3_Random vs. 3_COMPD: t-test independent samples, P_val:3.304e-83 t=1.952e+01
# 1_Random vs. 1_COMPD: t-test independent samples, P_val:1.207e-18 t=8.820e+00
# ...

# %%
# 12 doses (part of the supplement)
fig_name = "-12doses-dil4-half-columns-neg-controls-0.4"
relative_ic50_data_1rep = np.loadtxt(data_dir+'relative_ic50_data-24-12-dil4-1-0.4-20250706-right-half-neg-control-log-new-reg.csv', delimiter=',', dtype='str')
relative_ic50_data_2rep = np.loadtxt(data_dir+'relative_ic50_data-12-12-dil4-2-0.4-20250706-right-half-neg-control-log-new-reg.csv', delimiter=',', dtype='str')
relative_ic50_data_3rep = np.loadtxt(data_dir+'relative_ic50_data-8-12-dil4-3-0.4-20250706-right-half-neg-control-log-new-reg.csv', delimiter=',', dtype='str')

util.generate_relic50_r2(relative_ic50_data_1rep, relative_ic50_data_2rep, relative_ic50_data_3rep, fig_name, figures_dir, y_max_relic = y_max_relic, y_max_r2 = y_max_r2)
# Out:
# p-value annotation legend:
#       ns: 1.00e-04 < p <= 1.00e+00
#        *: 1.00e-12 < p <= 1.00e-04
#       **: 1.00e-43 < p <= 1.00e-12
#      ***: p <= 1.00e-43
#
# 2_Random vs. 2_PLAID: t-test independent samples, P_val:1.521e-08 t=5.664e+00
# 2_PLAID vs. 2_COMPD: t-test independent samples, P_val:1.032e-02 t=-2.565e+00
# 3_Random vs. 3_PLAID: t-test independent samples, P_val:1.738e-06 t=4.786e+00
# 3_PLAID vs. 3_COMPD: t-test independent samples, P_val:5.863e-01 t=-5.443e-01
# 1_Random vs. 1_PLAID: t-test independent samples, P_val:8.352e-23 t=9.843e+00
# 1_PLAID vs. 1_COMPD: t-test independent samples, P_val:1.091e-34 t=-1.231e+01
# 2_Random vs. 2_COMPD: t-test independent samples, P_val:5.870e-03 t=2.756e+00
# 3_Random vs. 3_COMPD: t-test independent samples, P_val:9.778e-05 t=3.899e+00
# 1_Random vs. 1_COMPD: t-test independent samples, P_val:3.083e-03 t=-2.960e+00
# ...

# %% [markdown]
# ### Manuscript
#
# Figure 2

# %%
# 8 doses (part of the supplement)
fig_name = "-8doses-dil8-half-columns-neg-controls-0.4_paper"

relative_ic50_data_1rep = np.loadtxt(data_dir+'relative_ic50_data-36-8-dil8-1-0.4-20250706-right-half-neg-control-log-new-reg.csv', delimiter=',', dtype='str')
relative_ic50_data_2rep = np.loadtxt(data_dir+'relative_ic50_data-18-8-dil8-2-0.4-20250706-right-half-neg-control-log-new-reg.csv', delimiter=',', dtype='str')
relative_ic50_data_3rep = np.loadtxt(data_dir+'relative_ic50_data-12-8-dil8-3-0.4-20250706-right-half-neg-control-log-new-reg.csv', delimiter=',', dtype='str')

util.generate_relic50_r2(relative_ic50_data_1rep, relative_ic50_data_2rep, relative_ic50_data_3rep, fig_name, figures_dir, y_max_r2 = 9)

## 3 replicates
util.create_latex_table_wide(relative_ic50_data_1rep, relative_ic50_data_2rep, relative_ic50_data_3rep, tables_dir+"relic50-table"+fig_name+".tex", table_text = "Relative \\ECIC{}", column_name="MSE")
util.create_latex_table_pvalues_wide(relative_ic50_data_1rep, relative_ic50_data_2rep, relative_ic50_data_3rep, tables_dir+"pvalues-relic50-table"+fig_name+".tex", table_text = "Relative \\ECIC{}", column_name="MSE")
# Out:
# p-value annotation legend:
#       ns: 1.00e-04 < p <= 1.00e+00
#        *: 1.00e-12 < p <= 1.00e-04
#       **: 1.00e-43 < p <= 1.00e-12
#      ***: p <= 1.00e-43
#
# 2_Random vs. 2_PLAID: t-test independent samples, P_val:2.658e-10 t=6.322e+00
# 2_PLAID vs. 2_COMPD: t-test independent samples, P_val:8.964e-20 t=-9.114e+00
# 3_Random vs. 3_PLAID: t-test independent samples, P_val:6.319e-28 t=1.099e+01
# 3_PLAID vs. 3_COMPD: t-test independent samples, P_val:2.184e-24 t=1.022e+01
# 1_Random vs. 1_PLAID: t-test independent samples, P_val:4.881e-25 t=1.034e+01
# 1_PLAID vs. 1_COMPD: t-test independent samples, P_val:3.197e-06 t=-4.659e+00
# 2_Random vs. 2_COMPD: t-test independent samples, P_val:8.185e-04 t=3.347e+00
# 3_Random vs. 3_COMPD: t-test independent samples, P_val:3.304e-83 t=1.952e+01
# 1_Random vs. 1_COMPD: t-test independent samples, P_val:1.207e-18 t=8.820e+00
# ...

# %% [markdown]
# ## Evaluating Residuals
#
# We now look at the residuals compared to the sigmoid used to generated the data
#
# ### Bowl-shaped plate effects

# %%
y_max_res = 450

# %%
# 6 doses (currently on the supplement. Not using neg controls in the curve)
fig_name = "-1-2-3-6doses-dil18-bowl-0.055"

residuals_1rep = np.loadtxt(data_dir+'residuals-48-6-dil18-1-0.055-20250706-curve_info-new-reg.csv', delimiter=',', dtype='str')
residuals_2rep = np.loadtxt(data_dir+'residuals-24-6-dil18-2-0.055-20250706-curve_info-new-reg.csv', delimiter=',', dtype='str')
residuals_3rep = np.loadtxt(data_dir+'residuals-16-6-dil18-3-0.055-20250706-curve_info-new-reg.csv', delimiter=',', dtype='str')

util.plot_barplot_residuals_data(residuals_1rep, residuals_2rep, residuals_3rep, fig_name, y_max=y_max_res, leg_loc="upper center", fig_dir=figures_dir)
# Out:
# p-value annotation legend:
#       ns: 1.00e-04 < p <= 1.00e+00
#        *: 1.00e-12 < p <= 1.00e-04
#       **: 1.00e-43 < p <= 1.00e-12
#      ***: p <= 1.00e-43
#
# 2_Random vs. 2_PLAID: t-test independent samples, P_val:1.525e-252 t=3.399e+01
# 2_PLAID vs. 2_COMPD: t-test independent samples, P_val:2.603e-17 t=8.464e+00
# 3_Random vs. 3_PLAID: t-test independent samples, P_val:1.747e-298 t=3.698e+01
# 3_PLAID vs. 3_COMPD: t-test independent samples, P_val:4.710e-49 t=-1.472e+01
# 1_Random vs. 1_PLAID: t-test independent samples, P_val:0.000e+00 t=4.234e+01
# 1_PLAID vs. 1_COMPD: t-test independent samples, P_val:1.919e-01 t=1.305e+00
# 2_Random vs. 2_COMPD: t-test independent samples, P_val:0.000e+00 t=3.980e+01
# 3_Random vs. 3_COMPD: t-test independent samples, P_val:5.690e-110 t=2.229e+01
# 1_Random vs. 1_COMPD: t-test independent samples, P_val:0.000e+00 t=4.275e+01

# %%
# 6 doses (currently on the supplement. Not using neg controls in the curve)
fig_name = "-1-2-3-6doses-dil18-bowl-0.085"

residuals_1rep = np.loadtxt(data_dir+'residuals-48-6-dil18-1-0.085-20250706-curve_info-new-reg.csv', delimiter=',', dtype='str')
residuals_2rep = np.loadtxt(data_dir+'residuals-24-6-dil18-2-0.085-20250706-curve_info-new-reg.csv', delimiter=',', dtype='str')
residuals_3rep = np.loadtxt(data_dir+'residuals-16-6-dil18-3-0.085-20250706-curve_info-new-reg.csv', delimiter=',', dtype='str')

util.plot_barplot_residuals_data(residuals_1rep, residuals_2rep, residuals_3rep, fig_name, y_max=y_max_res, fig_dir=figures_dir)
# Out:
# p-value annotation legend:
#       ns: 1.00e-04 < p <= 1.00e+00
#        *: 1.00e-12 < p <= 1.00e-04
#       **: 1.00e-43 < p <= 1.00e-12
#      ***: p <= 1.00e-43
#
# 2_Random vs. 2_PLAID: t-test independent samples, P_val:2.453e-274 t=3.544e+01
# 2_PLAID vs. 2_COMPD: t-test independent samples, P_val:2.783e-22 t=9.709e+00
# 3_Random vs. 3_PLAID: t-test independent samples, P_val:0.000e+00 t=3.868e+01
# 3_PLAID vs. 3_COMPD: t-test independent samples, P_val:8.299e-55 t=-1.560e+01
# 1_Random vs. 1_PLAID: t-test independent samples, P_val:0.000e+00 t=4.319e+01
# 1_PLAID vs. 1_COMPD: t-test independent samples, P_val:5.436e-02 t=1.924e+00
# 2_Random vs. 2_COMPD: t-test independent samples, P_val:0.000e+00 t=4.176e+01
# 3_Random vs. 3_COMPD: t-test independent samples, P_val:1.419e-119 t=2.326e+01
# 1_Random vs. 1_COMPD: t-test independent samples, P_val:0.000e+00 t=4.394e+01

# %%
# 8 doses (currently on the supplement. Not using neg controls in the curve)
fig_name = "-1-2-3-8doses-dil8-bowl-0.055"

residuals_1rep = np.loadtxt(data_dir+'residuals-36-8-dil8-1-0.055-20250706-curve_info-new-reg.csv', delimiter=',', dtype='str')
residuals_2rep = np.loadtxt(data_dir+'residuals-18-8-dil8-2-0.055-20250706-curve_info-new-reg.csv', delimiter=',', dtype='str')
residuals_3rep = np.loadtxt(data_dir+'residuals-12-8-dil8-3-0.055-20250706-curve_info-new-reg.csv', delimiter=',', dtype='str')

util.plot_barplot_residuals_data(residuals_1rep, residuals_2rep, residuals_3rep, fig_name, y_max=y_max_res, leg_loc="upper center", fig_dir=figures_dir)
# Out:
# p-value annotation legend:
#       ns: 1.00e-04 < p <= 1.00e+00
#        *: 1.00e-12 < p <= 1.00e-04
#       **: 1.00e-43 < p <= 1.00e-12
#      ***: p <= 1.00e-43
#
# 2_Random vs. 2_PLAID: t-test independent samples, P_val:0.000e+00 t=3.994e+01
# 2_PLAID vs. 2_COMPD: t-test independent samples, P_val:4.508e-02 t=-2.004e+00
# 3_Random vs. 3_PLAID: t-test independent samples, P_val:0.000e+00 t=3.959e+01
# 3_PLAID vs. 3_COMPD: t-test independent samples, P_val:1.357e-07 t=-5.271e+00
# 1_Random vs. 1_PLAID: t-test independent samples, P_val:0.000e+00 t=4.338e+01
# 1_PLAID vs. 1_COMPD: t-test independent samples, P_val:5.729e-10 t=-6.198e+00
# 2_Random vs. 2_COMPD: t-test independent samples, P_val:0.000e+00 t=3.947e+01
# 3_Random vs. 3_COMPD: t-test independent samples, P_val:3.206e-279 t=3.576e+01
# 1_Random vs. 1_COMPD: t-test independent samples, P_val:0.000e+00 t=3.938e+01

# %%
# 8 doses (currently on the supplement. Not using neg controls in the curve)
fig_name = "-1-2-3-8doses-dil8-bowl-0.085"

residuals_1rep = np.loadtxt(data_dir+'residuals-36-8-dil8-1-0.085-20250706-curve_info-new-reg.csv', delimiter=',', dtype='str')
residuals_2rep = np.loadtxt(data_dir+'residuals-18-8-dil8-2-0.085-20250706-curve_info-new-reg.csv', delimiter=',', dtype='str')
residuals_3rep = np.loadtxt(data_dir+'residuals-12-8-dil8-3-0.085-20250706-curve_info-new-reg.csv', delimiter=',', dtype='str')
20250706
util.plot_barplot_residuals_data(residuals_1rep, residuals_2rep, residuals_3rep, fig_name, y_max=y_max_res, fig_dir=figures_dir)
# Out:
# p-value annotation legend:
#       ns: 1.00e-04 < p <= 1.00e+00
#        *: 1.00e-12 < p <= 1.00e-04
#       **: 1.00e-43 < p <= 1.00e-12
#      ***: p <= 1.00e-43
#
# 2_Random vs. 2_PLAID: t-test independent samples, P_val:0.000e+00 t=4.165e+01
# 2_PLAID vs. 2_COMPD: t-test independent samples, P_val:9.846e-01 t=-1.934e-02
# 3_Random vs. 3_PLAID: t-test independent samples, P_val:0.000e+00 t=4.137e+01
# 3_PLAID vs. 3_COMPD: t-test independent samples, P_val:7.113e-06 t=-4.490e+00
# 1_Random vs. 1_PLAID: t-test independent samples, P_val:0.000e+00 t=4.516e+01
# 1_PLAID vs. 1_COMPD: t-test independent samples, P_val:1.023e-03 t=-3.284e+00
# 2_Random vs. 2_COMPD: t-test independent samples, P_val:0.000e+00 t=4.258e+01
# 3_Random vs. 3_COMPD: t-test independent samples, P_val:0.000e+00 t=3.832e+01
# 1_Random vs. 1_COMPD: t-test independent samples, P_val:0.000e+00 t=4.330e+01

# %%
# 12 doses (currently on the supplement. Not using neg controls in the curve)
fig_name = "-1-2-3-12doses-dil4-bowl-0.055"

residuals_1rep = np.loadtxt(data_dir+'residuals-24-12-dil4-1-0.055-20250706-curve_info-new-reg.csv', delimiter=',', dtype='str')
residuals_2rep = np.loadtxt(data_dir+'residuals-12-12-dil4-2-0.055-20250706-curve_info-new-reg.csv', delimiter=',', dtype='str')
residuals_3rep = np.loadtxt(data_dir+'residuals-8-12-dil4-3-0.055-20250706-curve_info-new-reg.csv', delimiter=',', dtype='str')

util.plot_barplot_residuals_data(residuals_1rep, residuals_2rep, residuals_3rep, fig_name, y_max=y_max_res, leg_loc="upper center", fig_dir=figures_dir)
# Out:
# p-value annotation legend:
#       ns: 1.00e-04 < p <= 1.00e+00
#        *: 1.00e-12 < p <= 1.00e-04
#       **: 1.00e-43 < p <= 1.00e-12
#      ***: p <= 1.00e-43
#
# 2_Random vs. 2_PLAID: t-test independent samples, P_val:0.000e+00 t=3.899e+01
# 2_PLAID vs. 2_COMPD: t-test independent samples, P_val:9.640e-49 t=-1.468e+01
# 3_Random vs. 3_PLAID: t-test independent samples, P_val:0.000e+00 t=4.394e+01
# 3_PLAID vs. 3_COMPD: t-test independent samples, P_val:1.033e-21 t=-9.574e+00
# 1_Random vs. 1_PLAID: t-test independent samples, P_val:5.803e-215 t=3.133e+01
# 1_PLAID vs. 1_COMPD: t-test independent samples, P_val:2.407e-59 t=1.625e+01
# 2_Random vs. 2_COMPD: t-test independent samples, P_val:7.892e-143 t=2.546e+01
# 3_Random vs. 3_COMPD: t-test independent samples, P_val:1.204e-271 t=3.526e+01
# 1_Random vs. 1_COMPD: t-test independent samples, P_val:0.000e+00 t=4.305e+01

# %%
# 12 doses (currently on the supplement. Not using neg controls in the curve)
fig_name = "-1-2-3-12doses-dil4-bowl-0.085"

residuals_1rep = np.loadtxt(data_dir+'residuals-24-12-dil4-1-0.085-20250706-curve_info-new-reg.csv', delimiter=',', dtype='str')
residuals_2rep = np.loadtxt(data_dir+'residuals-12-12-dil4-2-0.085-20250706-curve_info-new-reg.csv', delimiter=',', dtype='str')
residuals_3rep = np.loadtxt(data_dir+'residuals-8-12-dil4-3-0.085-20250706-curve_info-new-reg.csv', delimiter=',', dtype='str')

util.plot_barplot_residuals_data(residuals_1rep, residuals_2rep, residuals_3rep, fig_name, y_max=y_max_res, fig_dir=figures_dir)
# Out:
# p-value annotation legend:
#       ns: 1.00e-04 < p <= 1.00e+00
#        *: 1.00e-12 < p <= 1.00e-04
#       **: 1.00e-43 < p <= 1.00e-12
#      ***: p <= 1.00e-43
#
# 2_Random vs. 2_PLAID: t-test independent samples, P_val:0.000e+00 t=4.060e+01
# 2_PLAID vs. 2_COMPD: t-test independent samples, P_val:5.214e-55 t=-1.563e+01
# 3_Random vs. 3_PLAID: t-test independent samples, P_val:0.000e+00 t=4.520e+01
# 3_PLAID vs. 3_COMPD: t-test independent samples, P_val:5.262e-19 t=-8.907e+00
# 1_Random vs. 1_PLAID: t-test independent samples, P_val:1.135e-241 t=3.324e+01
# 1_PLAID vs. 1_COMPD: t-test independent samples, P_val:4.908e-64 t=1.690e+01
# 2_Random vs. 2_COMPD: t-test independent samples, P_val:1.953e-154 t=2.649e+01
# 3_Random vs. 3_COMPD: t-test independent samples, P_val:1.234e-300 t=3.712e+01
# 1_Random vs. 1_COMPD: t-test independent samples, P_val:0.000e+00 t=4.470e+01

# %% [markdown]
# ## Half columns
#
# ### Weaker plate effects

# %%
# 6 doses (part of the supplement)
fig_name = "-1-2-3-6doses-dil18-half-columns-neg-controls-0.2"

residuals_1rep = np.loadtxt(data_dir+'residuals-48-6-dil18-1-0.2-20250706-right-half-neg-control-log-new-reg.csv', delimiter=',', dtype='str')
residuals_2rep = np.loadtxt(data_dir+'residuals-24-6-dil18-2-0.2-20250706-right-half-neg-control-log-new-reg.csv', delimiter=',', dtype='str')
residuals_3rep = np.loadtxt(data_dir+'residuals-16-6-dil18-3-0.2-20250706-right-half-neg-control-log-new-reg.csv', delimiter=',', dtype='str')

util.plot_barplot_residuals_data(residuals_1rep, residuals_2rep, residuals_3rep, fig_name, y_max=450, leg_loc="upper center", fig_dir=figures_dir)
# Out:
# p-value annotation legend:
#       ns: 1.00e-04 < p <= 1.00e+00
#        *: 1.00e-12 < p <= 1.00e-04
#       **: 1.00e-43 < p <= 1.00e-12
#      ***: p <= 1.00e-43
#
# 2_Random vs. 2_PLAID: t-test independent samples, P_val:1.041e-247 t=3.366e+01
# 2_PLAID vs. 2_COMPD: t-test independent samples, P_val:5.701e-10 t=6.199e+00
# 3_Random vs. 3_PLAID: t-test independent samples, P_val:3.576e-236 t=3.285e+01
# 3_PLAID vs. 3_COMPD: t-test independent samples, P_val:3.906e-03 t=-2.886e+00
# 1_Random vs. 1_PLAID: t-test independent samples, P_val:4.206e-237 t=3.292e+01
# 1_PLAID vs. 1_COMPD: t-test independent samples, P_val:9.465e-14 t=7.449e+00
# 2_Random vs. 2_COMPD: t-test independent samples, P_val:1.095e-285 t=3.617e+01
# 3_Random vs. 3_COMPD: t-test independent samples, P_val:8.047e-218 t=3.154e+01
# 1_Random vs. 1_COMPD: t-test independent samples, P_val:1.748e-284 t=3.609e+01

# %%
# 8 doses (part of the supplement)
fig_name = "-1-2-3-8doses-dil8-half-columns-neg-controls-0.2"

residuals_1rep = np.loadtxt(data_dir+'residuals-36-8-dil8-1-0.2-20250706-right-half-neg-control-log-new-reg.csv', delimiter=',', dtype='str')
residuals_2rep = np.loadtxt(data_dir+'residuals-18-8-dil8-2-0.2-20250706-right-half-neg-control-log-new-reg.csv', delimiter=',', dtype='str')
residuals_3rep = np.loadtxt(data_dir+'residuals-12-8-dil8-3-0.2-20250706-right-half-neg-control-log-new-reg.csv', delimiter=',', dtype='str')

util.plot_barplot_residuals_data(residuals_1rep, residuals_2rep, residuals_3rep, fig_name, y_max=450, leg_loc="upper center", fig_dir=figures_dir)
# Out:
# p-value annotation legend:
#       ns: 1.00e-04 < p <= 1.00e+00
#        *: 1.00e-12 < p <= 1.00e-04
#       **: 1.00e-43 < p <= 1.00e-12
#      ***: p <= 1.00e-43
#
# 2_Random vs. 2_PLAID: t-test independent samples, P_val:1.111e-216 t=3.145e+01
# 2_PLAID vs. 2_COMPD: t-test independent samples, P_val:3.467e-17 t=8.430e+00
# 3_Random vs. 3_PLAID: t-test independent samples, P_val:7.792e-224 t=3.197e+01
# 3_PLAID vs. 3_COMPD: t-test independent samples, P_val:3.354e-02 t=2.126e+00
# 1_Random vs. 1_PLAID: t-test independent samples, P_val:3.370e-190 t=2.944e+01
# 1_PLAID vs. 1_COMPD: t-test independent samples, P_val:1.748e-11 t=6.726e+00
# 2_Random vs. 2_COMPD: t-test independent samples, P_val:3.235e-265 t=3.484e+01
# 3_Random vs. 3_COMPD: t-test independent samples, P_val:1.006e-233 t=3.268e+01
# 1_Random vs. 1_COMPD: t-test independent samples, P_val:1.068e-231 t=3.254e+01

# %%
# 12 doses (part of the supplement)
fig_name = "-1-2-3-12doses-dil4-half-columns-neg-controls-0.2"

residuals_1rep = np.loadtxt(data_dir+'residuals-24-12-dil4-1-0.2-20250706-right-half-neg-control-log-new-reg.csv', delimiter=',', dtype='str')
residuals_2rep = np.loadtxt(data_dir+'residuals-12-12-dil4-2-0.2-20250706-right-half-neg-control-log-new-reg.csv', delimiter=',', dtype='str')
residuals_3rep = np.loadtxt(data_dir+'residuals-8-12-dil4-3-0.2-20250706-right-half-neg-control-log-new-reg.csv', delimiter=',', dtype='str')

util.plot_barplot_residuals_data(residuals_1rep, residuals_2rep, residuals_3rep, fig_name, y_max=450, leg_loc="upper center", fig_dir=figures_dir)
# Out:
# p-value annotation legend:
#       ns: 1.00e-04 < p <= 1.00e+00
#        *: 1.00e-12 < p <= 1.00e-04
#       **: 1.00e-43 < p <= 1.00e-12
#      ***: p <= 1.00e-43
#
# 2_Random vs. 2_PLAID: t-test independent samples, P_val:4.151e-210 t=3.097e+01
# 2_PLAID vs. 2_COMPD: t-test independent samples, P_val:1.120e-40 t=-1.336e+01
# 3_Random vs. 3_PLAID: t-test independent samples, P_val:1.454e-236 t=3.288e+01
# 3_PLAID vs. 3_COMPD: t-test independent samples, P_val:9.220e-17 t=-8.315e+00
# 1_Random vs. 1_PLAID: t-test independent samples, P_val:8.079e-219 t=3.161e+01
# 1_PLAID vs. 1_COMPD: t-test independent samples, P_val:1.555e-55 t=1.570e+01
# 2_Random vs. 2_COMPD: t-test independent samples, P_val:1.061e-131 t=2.444e+01
# 3_Random vs. 3_COMPD: t-test independent samples, P_val:6.404e-187 t=2.919e+01
# 1_Random vs. 1_COMPD: t-test independent samples, P_val:0.000e+00 t=3.785e+01

# %% [markdown]
# ### Stronger plate effects

# %%
# 6 doses (part of the supplement)
fig_name = "-1-2-3-6doses-dil18-half-columns-neg-controls-0.4"

residuals_1rep = np.loadtxt(data_dir+'residuals-48-6-dil18-1-0.4-20250706-right-half-neg-control-log-new-reg.csv', delimiter=',', dtype='str')
residuals_2rep = np.loadtxt(data_dir+'residuals-24-6-dil18-2-0.4-20250706-right-half-neg-control-log-new-reg.csv', delimiter=',', dtype='str')
residuals_3rep = np.loadtxt(data_dir+'residuals-16-6-dil18-3-0.4-20250706-right-half-neg-control-log-new-reg.csv', delimiter=',', dtype='str')

util.plot_barplot_residuals_data(residuals_1rep, residuals_2rep, residuals_3rep, fig_name, y_max=450, fig_dir=figures_dir)
# Out:
# p-value annotation legend:
#       ns: 1.00e-04 < p <= 1.00e+00
#        *: 1.00e-12 < p <= 1.00e-04
#       **: 1.00e-43 < p <= 1.00e-12
#      ***: p <= 1.00e-43
#
# 2_Random vs. 2_PLAID: t-test independent samples, P_val:1.545e-260 t=3.453e+01
# 2_PLAID vs. 2_COMPD: t-test independent samples, P_val:7.134e-17 t=8.345e+00
# 3_Random vs. 3_PLAID: t-test independent samples, P_val:1.180e-241 t=3.324e+01
# 3_PLAID vs. 3_COMPD: t-test independent samples, P_val:5.286e-02 t=-1.936e+00
# 1_Random vs. 1_PLAID: t-test independent samples, P_val:3.130e-248 t=3.369e+01
# 1_PLAID vs. 1_COMPD: t-test independent samples, P_val:2.290e-14 t=7.634e+00
# 2_Random vs. 2_COMPD: t-test independent samples, P_val:3.946e-309 t=3.764e+01
# 3_Random vs. 3_COMPD: t-test independent samples, P_val:1.002e-229 t=3.240e+01
# 1_Random vs. 1_COMPD: t-test independent samples, P_val:1.180e-294 t=3.674e+01

# %%
# 8 doses (part of the supplement)
fig_name = "-1-2-3-8doses-dil8-half-columns-neg-controls-0.4"

residuals_1rep = np.loadtxt(data_dir+'residuals-36-8-dil8-1-0.4-20250706-right-half-neg-control-log-new-reg.csv', delimiter=',', dtype='str')
residuals_2rep = np.loadtxt(data_dir+'residuals-18-8-dil8-2-0.4-20250706-right-half-neg-control-log-new-reg.csv', delimiter=',', dtype='str')
residuals_3rep = np.loadtxt(data_dir+'residuals-12-8-dil8-3-0.4-20250706-right-half-neg-control-log-new-reg.csv', delimiter=',', dtype='str')

util.plot_barplot_residuals_data(residuals_1rep, residuals_2rep, residuals_3rep, fig_name, y_max=450, fig_dir=figures_dir)
# Out:
# p-value annotation legend:
#       ns: 1.00e-04 < p <= 1.00e+00
#        *: 1.00e-12 < p <= 1.00e-04
#       **: 1.00e-43 < p <= 1.00e-12
#      ***: p <= 1.00e-43
#
# 2_Random vs. 2_PLAID: t-test independent samples, P_val:8.452e-241 t=3.318e+01
# 2_PLAID vs. 2_COMPD: t-test independent samples, P_val:4.948e-16 t=8.113e+00
# 3_Random vs. 3_PLAID: t-test independent samples, P_val:2.924e-242 t=3.328e+01
# 3_PLAID vs. 3_COMPD: t-test independent samples, P_val:5.152e-05 t=4.049e+00
# 1_Random vs. 1_PLAID: t-test independent samples, P_val:2.478e-216 t=3.143e+01
# 1_PLAID vs. 1_COMPD: t-test independent samples, P_val:1.320e-19 t=9.060e+00
# 2_Random vs. 2_COMPD: t-test independent samples, P_val:6.997e-287 t=3.625e+01
# 3_Random vs. 3_COMPD: t-test independent samples, P_val:6.960e-263 t=3.468e+01
# 1_Random vs. 1_COMPD: t-test independent samples, P_val:2.932e-271 t=3.524e+01

# %%
# 12 doses (part of the supplement)
fig_name = "-1-2-3-12doses-dil4-half-columns-neg-controls-0.4"

residuals_1rep = np.loadtxt(data_dir+'residuals-24-12-dil4-1-0.4-20250706-right-half-neg-control-log-new-reg.csv', delimiter=',', dtype='str')
residuals_2rep = np.loadtxt(data_dir+'residuals-12-12-dil4-2-0.4-20250706-right-half-neg-control-log-new-reg.csv', delimiter=',', dtype='str')
residuals_3rep = np.loadtxt(data_dir+'residuals-8-12-dil4-3-0.4-20250706-right-half-neg-control-log-new-reg.csv', delimiter=',', dtype='str')

util.plot_barplot_residuals_data(residuals_1rep, residuals_2rep, residuals_3rep, fig_name, y_max=450, fig_dir=figures_dir)
# Out:
# p-value annotation legend:
#       ns: 1.00e-04 < p <= 1.00e+00
#        *: 1.00e-12 < p <= 1.00e-04
#       **: 1.00e-43 < p <= 1.00e-12
#      ***: p <= 1.00e-43
#
# 2_Random vs. 2_PLAID: t-test independent samples, P_val:1.028e-224 t=3.204e+01
# 2_PLAID vs. 2_COMPD: t-test independent samples, P_val:1.492e-41 t=-1.351e+01
# 3_Random vs. 3_PLAID: t-test independent samples, P_val:1.857e-251 t=3.391e+01
# 3_PLAID vs. 3_COMPD: t-test independent samples, P_val:6.079e-12 t=-6.878e+00
# 1_Random vs. 1_PLAID: t-test independent samples, P_val:1.073e-234 t=3.275e+01
# 1_PLAID vs. 1_COMPD: t-test independent samples, P_val:1.437e-54 t=1.556e+01
# 2_Random vs. 2_COMPD: t-test independent samples, P_val:2.515e-134 t=2.468e+01
# 3_Random vs. 3_COMPD: t-test independent samples, P_val:1.899e-208 t=3.084e+01
# 1_Random vs. 1_COMPD: t-test independent samples, P_val:0.000e+00 t=3.889e+01

# %% [markdown]
# ### Manuscript
# Figure 2b

# %%
# 8 doses (part of the supplement)
fig_name = "-1-2-3-8doses-dil8-half-columns-neg-controls-0.4_paper"

residuals_1rep = np.loadtxt(data_dir+'residuals-36-8-dil8-1-0.4-20250706-right-half-neg-control-log-new-reg.csv', delimiter=',', dtype='str')
residuals_2rep = np.loadtxt(data_dir+'residuals-18-8-dil8-2-0.4-20250706-right-half-neg-control-log-new-reg.csv', delimiter=',', dtype='str')
residuals_3rep = np.loadtxt(data_dir+'residuals-12-8-dil8-3-0.4-20250706-right-half-neg-control-log-new-reg.csv', delimiter=',', dtype='str')

util.plot_barplot_residuals_data(residuals_1rep, residuals_2rep, residuals_3rep, fig_name, y_max=450, fig_dir=figures_dir)
# Out:
# p-value annotation legend:
#       ns: 1.00e-04 < p <= 1.00e+00
#        *: 1.00e-12 < p <= 1.00e-04
#       **: 1.00e-43 < p <= 1.00e-12
#      ***: p <= 1.00e-43
#
# 2_Random vs. 2_PLAID: t-test independent samples, P_val:8.452e-241 t=3.318e+01
# 2_PLAID vs. 2_COMPD: t-test independent samples, P_val:4.948e-16 t=8.113e+00
# 3_Random vs. 3_PLAID: t-test independent samples, P_val:2.924e-242 t=3.328e+01
# 3_PLAID vs. 3_COMPD: t-test independent samples, P_val:5.152e-05 t=4.049e+00
# 1_Random vs. 1_PLAID: t-test independent samples, P_val:2.478e-216 t=3.143e+01
# 1_PLAID vs. 1_COMPD: t-test independent samples, P_val:1.320e-19 t=9.060e+00
# 2_Random vs. 2_COMPD: t-test independent samples, P_val:6.997e-287 t=3.625e+01
# 3_Random vs. 3_COMPD: t-test independent samples, P_val:6.960e-263 t=3.468e+01
# 1_Random vs. 1_COMPD: t-test independent samples, P_val:2.932e-271 t=3.524e+01

# %% [markdown]
# # The End!
